# %%
import seaborn as sns

# %%
import pandas as pd
data = pd.read_csv("/home/ssk/Desktop/master-thesis/master-thesis-personalization/data/for-plotting/Master Thesis Experiment Results - summed_up_vs_concatenated.csv")

# %%
data
# Out:
#   reward scheme  summed_up_embeddings  concatenated
# 0        0 to 1             72.445062     70.715432
# 1        0 to 1             71.458025     70.971605
# 2        0 to 1             65.012963     70.632099
# 3        0 to 1             64.322840     68.448148
# 4        0 to 1             64.658642     64.858642
# 5        0 to 1             69.101235     63.371605
# 6        0 to 1             67.714815     69.217284
# 7        0 to 1             64.170988     62.221605
# 8        0 to 1             65.585802     67.132099
# 9        0 to 1             67.212346     64.720370

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with columns 'column1' and 'column2'
# Replace 'column1' and 'column2' with your actual column names


# Plotting using Seaborn
plt.figure(figsize=(10, 6))  
sns.lineplot(data=data[['summed_up_embeddings', 'concatenated']])
plt.xlabel('Iteration')  # Replace with your x-axis label
plt.ylabel('Reward')  # Replace with your y-axis label
plt.title('Compariosn between summed up and concatenated embeddings')  # Replace with your plot title
plt.show()

# %%
import pandas as pd
data = pd.read_csv("/home/ssk/Desktop/master-thesis/master-thesis-personalization/data/for-plotting/Master Thesis Experiment Results - with_vs_wo_tags.csv")
data
# Out:
#   reward_scheme  summed_up_with_tags  summed_up_without_tags
# 0        0_to_1            68.716049                   57.00
# 1        0_to_1            67.594444                   59.95
# 2        0_to_1            65.229012                   68.90
# 3        0_to_1            65.174691                   71.50
# 4        0_to_1            68.414815                   59.00
# 5        0_to_1            62.762963                   63.45
# 6        0_to_1            62.259259                   69.50
# 7        0_to_1            62.630864                   70.05
# 8        0_to_1            63.447531                   70.50
# 9        0_to_1            67.171605                   68.15

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with columns 'column1' and 'column2'
# Replace 'column1' and 'column2' with your actual column names


# Plotting using Seaborn
plt.figure(figsize=(12, 6))  
sns.lineplot(data=data[['summed_up_with_tags', 'summed_up_without_tags']])
plt.xlabel('Iteration')  # Replace with your x-axis label
plt.ylabel('Reward')  # Replace with your y-axis label
plt.title('Compariosn between with and without tags')  # Replace with your plot title
plt.show()

# %%
import pandas as pd
data = pd.read_csv("/home/ssk/Desktop/master-thesis/master-thesis-personalization/data/for-plotting/Master Thesis Experiment Results - with_vs_wo_tags.csv")
data
