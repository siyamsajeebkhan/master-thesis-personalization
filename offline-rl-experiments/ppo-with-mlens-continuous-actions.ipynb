# %% [markdown]
# ### Imports

# %%
import sys
import os
import base64
import pickle
import zlib
import gym
import numpy as np
import pandas as pd
import torch as th
from torch import nn, tensor
from collections import deque
from gym.spaces import Box, Discrete
from stable_baselines3 import PPO
from stable_baselines3.ppo import CnnPolicy
from stable_baselines3.common import results_plotter
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.vec_env.subproc_vec_env import SubprocVecEnv
from stable_baselines3.common.vec_env.base_vec_env import VecEnv
# from stable_baselines3.common.policies import BasePolicy, register_policy
import time
from datetime import date
from matplotlib import pyplot as plt
import torch
# %matplotlib inline

# %% [markdown]
# #### Movielens Env

# %%
import gymnasium as gym
from gymnasium import spaces, Space

import random
import pickle
import numpy as np
from tqdm import tqdm
import time
from sklearn.metrics.pairwise import cosine_similarity

class CustomActionSpace(Space):
    def __init__(self, shape=None, dtype=None):
        super().__init__(shape, dtype)
        actions = np.arange(0.5, 5.5, 0.5)
        self.actions_map = {idx: action for idx, action in enumerate(actions)}
        self.actions = list(self.actions_map.keys())
    
class MovieLensEnv(gym.Env):
    
    def __init__(self, data, action_vocab, movie_embed_to_id, movies_ratings_and_tags, use_prev_temp_as_feature=False, van_specific_embeddings=None, pbar=None, eval_mode='no'):
        self.dataset = data

        super(MovieLensEnv, self).__init__()

        self.current_step = 0
        self.max_steps = sum(len(traj['observations']) for traj in self.dataset)
        self.act_dim = self.dataset[0]['actions'].shape[1]

        self.low_action_space = [-1.0] * 8  # Lower bounds for each dimension
        self.high_action_space = [1.0] * 8  # Upper bounds for each dimension

        # self.action_space = spaces.box.Box(low=-1, high=1, shape=(self.act_dim,), dtype=np.float32)
        self.action_space = spaces.Box(low=np.array(self.low_action_space), high=np.array(self.high_action_space), dtype=np.float32)
        self.observation_space = spaces.Box(low=0, high=1, shape=(self.dataset[0]['observations'].shape[1],), dtype=np.float32)
        # self.observation_space = Space(shape=(self.dataset[0]['observations'].shape[1],), dtype=np.float32)
        self.sampled_idx = None
        self.action = None
        self.reward = None
        self.pbar = pbar
        self.total_steps = 0
        self.use_prev_temp = use_prev_temp_as_feature
        self.personalized_features = van_specific_embeddings
        self.movies_ratings_and_tags = movies_ratings_and_tags
        self.movie_embed_to_id = movie_embed_to_id
        self.action_vocab = action_vocab
        self.eval_mode = eval_mode

    def step(self, action):
        # print(f"Back to stepping")
        raw_action = action

        # Need to create a mapping between actions and rewards
        # If the movie is actually rated by the user: then the reward is the user's rating
        # Else, the reward is the average rating of all users for the movie
        # if np.isnan(raw_action).sum() > 0:
        #     print(f"raw_action: {raw_action}")
        # print(f"raw_action: {raw_action}")
        similarities = cosine_similarity(raw_action.reshape(1, -1), self.action_vocab)

        # Find indices of closest neighbors for each prediction in the batch
        closest_indices = np.argmax(similarities, axis=1)

        # print(f"closest_indices.shape: {closest_indices.shape}")
        closest_vectors = self.action_vocab[closest_indices]

        final_action = closest_vectors.reshape(-1)

        # print(f"final action: {final_action}, shape: {final_action.shape}")
        # First let's find the movie_id from the embed
        movie_id = self.movie_embed_to_id[tuple(final_action)]
        user_id = self.dataset[self.sampled_idx]['user_id']

        rating_by_user = self.movies_ratings_and_tags[(self.movies_ratings_and_tags['movieId'] == movie_id) & (self.movies_ratings_and_tags['userId'] == user_id)]['rating']

        if rating_by_user.any():
            self.reward = rating_by_user.values[0]
        else:
            self.reward = self.movies_ratings_and_tags[self.movies_ratings_and_tags['movieId'] == movie_id]['rating_global'].mean()

        # Round to nearest 0.5
        def round_to_nearest_half(number):
            return round(number * 2) / 2

        # Example usage
        self.reward = round_to_nearest_half(self.reward)
        done = False
        

        if self.pbar is not None:
            self.pbar.set_description(f"(idx, step): ({self.sampled_idx}, {self.current_step}) | predicted movie_id: {movie_id} | reward: {self.reward:.2f}")
            # time.sleep(0.25)
        self.current_step += 1
        obs, done = self._next_observation()

        print(f"Step: {self.total_steps} | Predicted movie_id: {movie_id} | reward: {self.reward}")
        self.total_steps += 1

        # return obs, self.reward, done, None, {}
        print(f"eval_mode: {self.eval_mode}")
        if self.eval_mode == 'yes':
            print(f"Eval mode true")
            return obs, self.reward, done, None, final_action
        else:
            return obs, self.reward, done, None, {}
    
    def reset(self, seed=None):
        # print(f"Reset method called")
        self.sampled_idx = random.randint(0, len(self.dataset) - 1)
        self.current_step = 0
        traj = self.dataset[self.sampled_idx]
        user_id = traj['user_id']

        obs = traj['observations'][self.current_step]

        if self.personalized_features is not None:
            obs = np.hstack((obs, self.personalized_features[user_id]))
        # print(f"returning from reset()")print()
        # return obs, None
        return obs, False
    
    def _next_observation(self):
        if self.dataset[self.sampled_idx]['terminals'][self.current_step]:
            done = True
            obs, _ = self.reset()
            return obs, done
        
        traj = self.dataset[self.sampled_idx]
        user_id = traj['user_id']
        obs = traj['observations'][self.current_step]
        if self.personalized_features is not None:
            obs = np.hstack((obs, self.personalized_features[user_id]))
        done = False
        return obs, done

    def eval(self):
        self.training = False
        
    def get_true_temperature(self):
        target_temperature = self.dataset[self.sampled_idx]['actions'][self.current_step]
        target_temperature = self.action_space.actions_map[target_temperature]
        return target_temperature

# %% [markdown]
# ### Different Versions of the data with different reward schemes

# %%
# from copy import deepcopy
# with open("../data/dt-datasets/movielens/processed-data/all_trajectories_with_concatenated_movname_genres_tags_userid_reward_of_scale_5.pkl", 'rb') as f:
#     all_trajectories = pickle.load(f)
# # all_trajs_copy = deepcopy(all_trajectories)

# %%
# # Calculate the size for the training set
# np.random.seed(42)
# trajectories = all_trajectories
# indices = {i for i in range(len(trajectories))}
# train_indices = list(np.random.choice(list(indices), size=round(0.7*len(indices)), replace=False))
# remaining_indices = indices.difference(train_indices)
# test_indices = remaining_indices

# print(f"total train users: {len(train_indices)}")
# print(f"total test users: {len(test_indices)}")

# train_trajectories = [trajectories[idx]for idx in train_indices]
# test_trajectories = [trajectories[idx]for idx in test_indices]

# print("Train set:", len(train_trajectories))
# print("Test set:", len(test_trajectories))

# %% [markdown]
# #### Reward scheme 1: Naive reward: all observations marked with 1

# %%
# # train_data_copy = deepcopy(train_data)
# train_trajectories_copy = deepcopy(train_trajectories)
# for traj in train_trajectories_copy:
#     name_and_genre_embeds = traj['observations'][:, 0:768] + traj['observations'][:, 768:2*768]
#     traj['observations'] = np.concatenate((name_and_genre_embeds, traj['observations'][:, 3*768:]), axis=1)
#     # print(traj['observations'].shape)
#     traj['rewards'] =  np.ones_like(traj['rewards'])



# test_trajectories_copy = deepcopy(test_trajectories)
# for traj in test_trajectories_copy:
#     name_and_genre_embeds = traj['observations'][:, 0:768] + traj['observations'][:, 768:2*768]
#     traj['observations'] = np.concatenate((name_and_genre_embeds, traj['observations'][:, 3*768:]), axis=1)
#     traj['rewards'] =  np.ones_like(traj['rewards'])

    
# train_data_with_naive_rewards = train_trajectories_copy
# test_data_with_naive_rewards = test_trajectories_copy

# with open('data/train_data_with_naive_rewards.pkl', 'wb') as f:
#     pickle.dump(train_data_with_naive_rewards, f)

# with open('data/test_data_with_naive_rewards.pkl', 'wb') as f:
#     pickle.dump(test_data_with_naive_rewards, f)

# %% [markdown]
# #### Reward scheme 2: Proximity based reward: scaled reward in the range of 0 and 1

# %%
# train_trajectories_copy = deepcopy(train_trajectories)
# highest_rating = 5.0
# for traj in train_trajectories_copy:
#     name_and_genre_embeds = traj['observations'][:, 0:768] + traj['observations'][:, 768:2*768]
#     traj['observations'] = np.concatenate((name_and_genre_embeds, traj['observations'][:, 3*768:]), axis=1)
#     # print(traj['observations'].shape)
#     errors = abs(highest_rating - traj['targets'])
#     traj['rewards'] = (1- (errors / 4.5)) ** 2

# test_trajectories_copy = deepcopy(test_trajectories)
# for traj in test_trajectories_copy:
#     name_and_genre_embeds = traj['observations'][:, 0:768] + traj['observations'][:, 768:2*768]
#     traj['observations'] = np.concatenate((name_and_genre_embeds, traj['observations'][:, 3*768:]), axis=1)
#     # print(traj['observations'].shape)
#     errors = abs(highest_rating - traj['targets'])
#     traj['rewards'] = (1- (errors / 4.5)) ** 2

# train_data_with_range_rewards = train_trajectories_copy
# test_data_with_range_rewards = test_trajectories_copy

# with open('data/train_data_with_range_rewards.pkl', 'wb') as f:
#     pickle.dump(train_data_with_range_rewards, f)

# with open('data/test_data_with_range_rewards.pkl', 'wb') as f:
#     pickle.dump(test_data_with_range_rewards, f)

# %% [markdown]
# #### Reward scheme 3: Binary reward: 1 or 0; 1 if liked 0 if not

# %%
# train_trajectories_copy = deepcopy(train_trajectories)
# threshold = 3.5
# for traj in train_trajectories_copy:
#     name_and_genre_embeds = traj['observations'][:, 0:768] + traj['observations'][:, 768:2*768]
#     traj['observations'] = np.concatenate((name_and_genre_embeds, traj['observations'][:, 3*768:]), axis=1)
#     # print(traj['observations'].shape)
#     errors = abs(highest_rating - traj['targets'])
#     traj['rewards'] = (traj['targets'] >= threshold).astype(int)


# test_trajectories_copy = deepcopy(test_trajectories)
# for traj in test_trajectories_copy:
#     name_and_genre_embeds = traj['observations'][:, 0:768] + traj['observations'][:, 768:2*768]
#     traj['observations'] = np.concatenate((name_and_genre_embeds, traj['observations'][:, 3*768:]), axis=1)
#     # print(traj['observations'].shape)
#     errors = abs(highest_rating - traj['targets'])
#     traj['rewards'] = (traj['targets'] >= threshold).astype(int)

# train_data_with_binary_rewards = train_trajectories_copy
# test_data_with_binary_rewards = test_trajectories_copy

# with open('data/train_data_with_binary_rewards.pkl', 'wb') as f:
#     pickle.dump(train_data_with_binary_rewards, f)

# with open('data/test_data_with_binary_rewards.pkl', 'wb') as f:
#     pickle.dump(test_data_with_binary_rewards, f)

# %% [markdown]
# ### Experiment with RL methods

# %% [markdown]
# #### Set up the environment

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
import numpy as np

# Create a function to instantiate your custom environment
def create_custom_env(data, action_vocab, movie_embed_to_id, movies_ratings_and_tags, eval_mode='no'):
    return MovieLensEnv(data, action_vocab, movie_embed_to_id, movies_ratings_and_tags, eval_mode)  # Instantiate your custom environment

# Create a vectorized environment
# env = make_vec_env(create_custom_env, n_envs=4)

# %%
action_embed_shape = 8

train_data_path = f'../data/dt-datasets/movielens/train-test-sets/mlens-train-trajectories-movies-as-actions-reduced-from-768-to-{action_embed_shape}_with_tanh.pkl'
test_data_path = f'../data/dt-datasets/movielens/train-test-sets/mlens-test-trajectories-movies-as-actions-reduced-from-768-to-{action_embed_shape}_with_tanh.pkl'

movies_ratings_and_tags = pd.read_csv("../data/movies_ratings_and_tags_mlens_small.csv")
movies_ratings_and_tags.drop('Unnamed: 0', axis=1, inplace=True)
overall_ratings = movies_ratings_and_tags.groupby('movieId')['rating'].mean().reset_index()
# Merge the overall ratings back into the original DataFrame
movies_ratings_and_tags = movies_ratings_and_tags.merge(overall_ratings, on='movieId', suffixes=('', '_global'))

movie_embeds_to_id_map_path = f"../data/dt-datasets/movielens/processed-data/movie_embed_with_shape_{action_embed_shape}_to_id_mapping_with_tanh.pkl"

action_vocab_path = f"../data/dt-datasets/movielens/processed-data/action_vocab_of_shape_{action_embed_shape}_with_tanh.pkl"

with open(train_data_path, 'rb') as f:
    train_data = pickle.load(f)

with open(test_data_path, 'rb') as f:
    test_data = pickle.load(f)
# # Try normalizing the train_data between -1 and 1
# for traj in train_data:
#     traj['actions'] = 2 * (traj['actions'] - np.min(traj['actions'])) / (np.max(traj['actions']) - np.min(traj['actions'])) - 1
#     traj['observations'] = 2 * (traj['observations'] - np.min(traj['observations'])) / (np.max(traj['actions']) - np.min(traj['actions'])) - 1


with open(movie_embeds_to_id_map_path, 'rb') as f:
    movie_embed_to_id = pickle.load(f)

with open(action_vocab_path, 'rb') as f:
    action_vocab = pickle.load(f)

train_env = Monitor(create_custom_env(data=train_data, action_vocab=action_vocab, movie_embed_to_id=movie_embed_to_id, movies_ratings_and_tags=movies_ratings_and_tags, eval_mode=False))

# %%
# all_obs = []
# all_actions = []
# for traj in train_data:
#     all_obs.append(traj['observations'])
#     all_actions.append(traj['actions'])

# obss = np.concatenate(all_obs)
# actions = np.concatenate(all_actions)
# obss.shape, actions.shape

# %% [markdown]
# #### Vanilla DDPG

# %%
train_env.action_space.shape[-1]
# Out:
# 8

# %%
from stable_baselines3 import PPO

# The noise objects for DDPG
n_actions = train_env.action_space.shape[-1]


model = PPO("MlpPolicy", train_env, verbose=1, seed=123)
model.policy
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=8, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
model.learn(total_timesteps=1000, log_interval=1)
# Out:
# Step: 0 | Predicted movie_id: 4232 | reward: 4.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 7349 | reward: 3.0
# eval_mode: no
# Step: 2 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 3 | Predicted movie_id: 56060 | reward: 4.5
# eval_mode: no
# Step: 4 | Predicted movie_id: 81537 | reward: 3.0
# eval_mode: no
# Step: 5 | Predicted movie_id: 137218 | reward: 2.5
# eval_mode: no
# Step: 6 | Predicted movie_id: 62644 | reward: 3.5
# eval_mode: no
# Step: 7 | Predicted movie_id: 8684 | reward: 3.5
# eval_mode: no
# Step: 8 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 9 | Predicted movie_id: 2765 | reward: 3.5
# eval_mode: no
# Step: 10 | Predicted movie_id: 1747 | reward: 3.5
# eval_mode: no
# Step: 11 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 12 | Predicted movie_id: 136598 | reward: 3.5
# eval_mode: no
# Step: 13 | Predicted movie_id: 2794 | reward: 2.5
# eval_mode: no
# Step: 14 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 15 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 16 | Predicted movie_id: 5400 | reward: 3.0
# eval_mode: no
# Step: 17 | Predicted movie_id: 129659 | reward: 3.5
# eval_mode: no
# Step: 18 | Predicted movie_id: 589 | reward: 4.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 142456 | reward: 4.0
# eval_mode: no
# Step: 20 | Predicted movie_id: 7742 | reward: 0.5
# eval_mode: no
# Step: 21 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 22 | Predicted movie_id: 307 | reward: 4.0
# eval_mode: no
# Step: 23 | Predicted movie_id: 8609 | reward: 3.0
# eval_mode: no
# Step: 24 | Predicted movie_id: 4677 | reward: 3.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 40414 | reward: 3.5
# eval_mode: no
# Step: 26 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 27 | Predicted movie_id: 143969 | reward: 3.0
# eval_mode: no
# Step: 28 | Predicted movie_id: 144262 | reward: 2.0
# eval_mode: no
# Step: 29 | Predicted movie_id: 7009 | reward: 3.5
# eval_mode: no
# Step: 30 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 31 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 32 | Predicted movie_id: 2185 | reward: 4.0
# eval_mode: no
# Step: 33 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 34 | Predicted movie_id: 7762 | reward: 3.5
# eval_mode: no
# Step: 35 | Predicted movie_id: 5353 | reward: 3.0
# eval_mode: no
# Step: 36 | Predicted movie_id: 64620 | reward: 4.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 6772 | reward: 3.0
# eval_mode: no
# Step: 38 | Predicted movie_id: 1844 | reward: 4.0
# eval_mode: no
# Step: 39 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 40 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 41 | Predicted movie_id: 101072 | reward: 2.5
# eval_mode: no
# Step: 42 | Predicted movie_id: 484 | reward: 3.0
# eval_mode: no
# Step: 43 | Predicted movie_id: 880 | reward: 2.5
# eval_mode: no
# Step: 44 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 45 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 46 | Predicted movie_id: 6386 | reward: 4.0
# eval_mode: no
# Step: 47 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 48 | Predicted movie_id: 8484 | reward: 4.5
# eval_mode: no
# Step: 49 | Predicted movie_id: 44943 | reward: 5.0
# eval_mode: no
# Step: 50 | Predicted movie_id: 130498 | reward: 3.5
# eval_mode: no
# Step: 51 | Predicted movie_id: 6947 | reward: 3.5
# eval_mode: no
# Step: 52 | Predicted movie_id: 2185 | reward: 4.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 54 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 55 | Predicted movie_id: 3053 | reward: 4.0
# eval_mode: no
# Step: 56 | Predicted movie_id: 3769 | reward: 3.5
# eval_mode: no
# Step: 57 | Predicted movie_id: 2360 | reward: 4.5
# eval_mode: no
# Step: 58 | Predicted movie_id: 4852 | reward: 1.5
# eval_mode: no
# Step: 59 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 60 | Predicted movie_id: 134849 | reward: 4.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 63 | Predicted movie_id: 34072 | reward: 3.5
# eval_mode: no
# Step: 64 | Predicted movie_id: 42011 | reward: 2.0
# eval_mode: no
# Step: 65 | Predicted movie_id: 6378 | reward: 3.5
# eval_mode: no
# Step: 66 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 67 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 68 | Predicted movie_id: 6625 | reward: 2.5
# eval_mode: no
# Step: 69 | Predicted movie_id: 3920 | reward: 4.0
# eval_mode: no
# Step: 70 | Predicted movie_id: 167036 | reward: 4.0
# eval_mode: no
# Step: 71 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 73 | Predicted movie_id: 1177 | reward: 4.0
# eval_mode: no
# Step: 74 | Predicted movie_id: 135803 | reward: 3.5
# eval_mode: no
# Step: 75 | Predicted movie_id: 5955 | reward: 3.5
# eval_mode: no
# Step: 76 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 77 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 78 | Predicted movie_id: 34072 | reward: 3.5
# eval_mode: no
# Step: 79 | Predicted movie_id: 86593 | reward: 2.5
# eval_mode: no
# Step: 80 | Predicted movie_id: 232 | reward: 4.0
# eval_mode: no
# Step: 81 | Predicted movie_id: 31225 | reward: 3.0
# eval_mode: no
# Step: 82 | Predicted movie_id: 948 | reward: 4.0
# eval_mode: no
# Step: 83 | Predicted movie_id: 32875 | reward: 3.0
# eval_mode: no
# Step: 84 | Predicted movie_id: 59429 | reward: 3.0
# eval_mode: no
# Step: 85 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 86 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 87 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 199 | reward: 4.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 90 | Predicted movie_id: 8755 | reward: 3.0
# eval_mode: no
# Step: 91 | Predicted movie_id: 167036 | reward: 4.0
# eval_mode: no
# Step: 92 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 93 | Predicted movie_id: 1021 | reward: 2.5
# eval_mode: no
# Step: 94 | Predicted movie_id: 1286 | reward: 3.0
# eval_mode: no
# Step: 95 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 96 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 97 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 98 | Predicted movie_id: 84696 | reward: 4.0
# eval_mode: no
# Step: 99 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 100 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 101 | Predicted movie_id: 2445 | reward: 2.5
# eval_mode: no
# Step: 102 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 103 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 104 | Predicted movie_id: 2052 | reward: 3.0
# eval_mode: no
# Step: 105 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 106 | Predicted movie_id: 2360 | reward: 4.5
# eval_mode: no
# Step: 107 | Predicted movie_id: 725 | reward: 2.5
# eval_mode: no
# Step: 108 | Predicted movie_id: 4068 | reward: 2.5
# eval_mode: no
# Step: 109 | Predicted movie_id: 8484 | reward: 4.5
# eval_mode: no
# Step: 110 | Predicted movie_id: 8622 | reward: 3.5
# eval_mode: no
# Step: 111 | Predicted movie_id: 2093 | reward: 3.0
# eval_mode: no
# Step: 112 | Predicted movie_id: 33124 | reward: 3.5
# eval_mode: no
# Step: 113 | Predicted movie_id: 2414 | reward: 3.5
# eval_mode: no
# Step: 114 | Predicted movie_id: 55620 | reward: 3.0
# eval_mode: no
# Step: 115 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 116 | Predicted movie_id: 1599 | reward: 2.5
# eval_mode: no
# Step: 117 | Predicted movie_id: 27820 | reward: 4.0
# eval_mode: no
# Step: 118 | Predicted movie_id: 7925 | reward: 4.0
# eval_mode: no
# Step: 119 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 120 | Predicted movie_id: 104644 | reward: 0.5
# eval_mode: no
# Step: 121 | Predicted movie_id: 1973 | reward: 2.0
# eval_mode: no
# Step: 122 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 123 | Predicted movie_id: 55020 | reward: 4.5
# eval_mode: no
# Step: 124 | Predicted movie_id: 6939 | reward: 4.0
# eval_mode: no
# Step: 125 | Predicted movie_id: 97194 | reward: 1.0
# eval_mode: no
# Step: 126 | Predicted movie_id: 1695 | reward: 4.0
# eval_mode: no
# Step: 127 | Predicted movie_id: 4104 | reward: 1.5
# eval_mode: no
# Step: 128 | Predicted movie_id: 47423 | reward: 4.0
# eval_mode: no
# Step: 129 | Predicted movie_id: 69654 | reward: 3.5
# eval_mode: no
# Step: 130 | Predicted movie_id: 114494 | reward: 1.5
# eval_mode: no
# Step: 131 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 132 | Predicted movie_id: 1021 | reward: 2.5
# eval_mode: no
# Step: 133 | Predicted movie_id: 387 | reward: 2.5
# eval_mode: no
# Step: 134 | Predicted movie_id: 148166 | reward: 3.5
# eval_mode: no
# Step: 135 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 136 | Predicted movie_id: 51662 | reward: 3.5
# eval_mode: no
# Step: 137 | Predicted movie_id: 100527 | reward: 4.0
# eval_mode: no
# Step: 138 | Predicted movie_id: 6063 | reward: 3.5
# eval_mode: no
# Step: 139 | Predicted movie_id: 1176 | reward: 4.0
# eval_mode: no
# Step: 140 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 141 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 142 | Predicted movie_id: 103372 | reward: 3.5
# eval_mode: no
# Step: 143 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 144 | Predicted movie_id: 25797 | reward: 3.5
# eval_mode: no
# Step: 145 | Predicted movie_id: 1330 | reward: 1.5
# eval_mode: no
# Step: 146 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 147 | Predicted movie_id: 193565 | reward: 3.5
# eval_mode: no
# Step: 148 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 149 | Predicted movie_id: 90057 | reward: 4.0
# eval_mode: no
# Step: 150 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 151 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 152 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 153 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 154 | Predicted movie_id: 8670 | reward: 4.0
# eval_mode: no
# Step: 155 | Predicted movie_id: 158388 | reward: 2.5
# eval_mode: no
# Step: 156 | Predicted movie_id: 6985 | reward: 4.0
# eval_mode: no
# Step: 157 | Predicted movie_id: 36533 | reward: 2.0
# eval_mode: no
# Step: 158 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 159 | Predicted movie_id: 5361 | reward: 2.0
# eval_mode: no
# Step: 160 | Predicted movie_id: 54796 | reward: 3.5
# eval_mode: no
# Step: 161 | Predicted movie_id: 5353 | reward: 3.0
# eval_mode: no
# Step: 162 | Predicted movie_id: 5353 | reward: 3.0
# eval_mode: no
# Step: 163 | Predicted movie_id: 26225 | reward: 4.5
# eval_mode: no
# Step: 164 | Predicted movie_id: 138210 | reward: 3.5
# eval_mode: no
# Step: 165 | Predicted movie_id: 544 | reward: 2.5
# eval_mode: no
# Step: 166 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 167 | Predicted movie_id: 91126 | reward: 3.0
# eval_mode: no
# Step: 168 | Predicted movie_id: 36850 | reward: 4.0
# eval_mode: no
# Step: 169 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 170 | Predicted movie_id: 7063 | reward: 4.0
# eval_mode: no
# Step: 171 | Predicted movie_id: 89580 | reward: 4.0
# eval_mode: no
# Step: 172 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 173 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 174 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 175 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 176 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 177 | Predicted movie_id: 97194 | reward: 1.0
# eval_mode: no
# Step: 178 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 179 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 180 | Predicted movie_id: 8239 | reward: 4.0
# eval_mode: no
# Step: 181 | Predicted movie_id: 71910 | reward: 2.5
# eval_mode: no
# Step: 182 | Predicted movie_id: 168026 | reward: 4.0
# eval_mode: no
# Step: 183 | Predicted movie_id: 6811 | reward: 2.5
# eval_mode: no
# Step: 184 | Predicted movie_id: 7349 | reward: 3.0
# eval_mode: no
# Step: 185 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 186 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 187 | Predicted movie_id: 94677 | reward: 3.5
# eval_mode: no
# Step: 188 | Predicted movie_id: 149334 | reward: 3.0
# eval_mode: no
# Step: 189 | Predicted movie_id: 131749 | reward: 3.0
# eval_mode: no
# Step: 190 | Predicted movie_id: 56152 | reward: 3.5
# eval_mode: no
# Step: 191 | Predicted movie_id: 82242 | reward: 4.0
# eval_mode: no
# Step: 192 | Predicted movie_id: 2794 | reward: 2.5
# eval_mode: no
# Step: 193 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 194 | Predicted movie_id: 1735 | reward: 3.5
# eval_mode: no
# Step: 195 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 196 | Predicted movie_id: 38304 | reward: 4.5
# eval_mode: no
# Step: 197 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 198 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 199 | Predicted movie_id: 7700 | reward: 3.5
# eval_mode: no
# Step: 200 | Predicted movie_id: 4380 | reward: 4.0
# eval_mode: no
# Step: 201 | Predicted movie_id: 27899 | reward: 3.0
# eval_mode: no
# Step: 202 | Predicted movie_id: 4660 | reward: 4.0
# eval_mode: no
# Step: 203 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 204 | Predicted movie_id: 526 | reward: 4.0
# eval_mode: no
# Step: 205 | Predicted movie_id: 109864 | reward: 2.0
# eval_mode: no
# Step: 206 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 207 | Predicted movie_id: 144262 | reward: 2.0
# eval_mode: no
# Step: 208 | Predicted movie_id: 89759 | reward: 4.5
# eval_mode: no
# Step: 209 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 210 | Predicted movie_id: 2686 | reward: 4.0
# eval_mode: no
# Step: 211 | Predicted movie_id: 34072 | reward: 3.5
# eval_mode: no
# Step: 212 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 213 | Predicted movie_id: 97194 | reward: 1.0
# eval_mode: no
# Step: 214 | Predicted movie_id: 114494 | reward: 1.5
# eval_mode: no
# Step: 215 | Predicted movie_id: 8908 | reward: 3.5
# eval_mode: no
# Step: 216 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 217 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 218 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 219 | Predicted movie_id: 136449 | reward: 4.0
# eval_mode: no
# Step: 220 | Predicted movie_id: 140267 | reward: 4.0
# eval_mode: no
# Step: 221 | Predicted movie_id: 6881 | reward: 3.0
# eval_mode: no
# Step: 222 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 223 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 224 | Predicted movie_id: 44555 | reward: 4.0
# eval_mode: no
# Step: 225 | Predicted movie_id: 6985 | reward: 4.0
# eval_mode: no
# Step: 226 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 227 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 228 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 229 | Predicted movie_id: 31150 | reward: 2.0
# eval_mode: no
# Step: 230 | Predicted movie_id: 91628 | reward: 2.0
# eval_mode: no
# Step: 231 | Predicted movie_id: 94323 | reward: 2.5
# eval_mode: no
# Step: 232 | Predicted movie_id: 3633 | reward: 3.5
# eval_mode: no
# Step: 233 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 234 | Predicted movie_id: 41627 | reward: 3.5
# eval_mode: no
# Step: 235 | Predicted movie_id: 3855 | reward: 5.0
# eval_mode: no
# Step: 236 | Predicted movie_id: 65225 | reward: 4.5
# eval_mode: no
# Step: 237 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 238 | Predicted movie_id: 6063 | reward: 3.5
# eval_mode: no
# Step: 239 | Predicted movie_id: 86293 | reward: 3.0
# eval_mode: no
# Step: 240 | Predicted movie_id: 6772 | reward: 3.0
# eval_mode: no
# Step: 241 | Predicted movie_id: 2654 | reward: 3.5
# eval_mode: no
# Step: 242 | Predicted movie_id: 143896 | reward: 4.5
# eval_mode: no
# Step: 243 | Predicted movie_id: 6818 | reward: 5.0
# eval_mode: no
# Step: 244 | Predicted movie_id: 66097 | reward: 3.5
# eval_mode: no
# Step: 245 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 246 | Predicted movie_id: 263 | reward: 4.0
# eval_mode: no
# Step: 247 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 248 | Predicted movie_id: 948 | reward: 4.0
# eval_mode: no
# Step: 249 | Predicted movie_id: 1251 | reward: 4.0
# eval_mode: no
# Step: 250 | Predicted movie_id: 144262 | reward: 2.0
# eval_mode: no
# Step: 251 | Predicted movie_id: 136471 | reward: 3.5
# eval_mode: no
# Step: 252 | Predicted movie_id: 2918 | reward: 4.0
# eval_mode: no
# Step: 253 | Predicted movie_id: 6158 | reward: 3.0
# eval_mode: no
# Step: 254 | Predicted movie_id: 484 | reward: 3.0
# eval_mode: no
# Step: 255 | Predicted movie_id: 60333 | reward: 4.5
# eval_mode: no
# Step: 256 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 257 | Predicted movie_id: 86286 | reward: 2.0
# eval_mode: no
# Step: 258 | Predicted movie_id: 82093 | reward: 1.5
# eval_mode: no
# Step: 259 | Predicted movie_id: 97194 | reward: 1.0
# eval_mode: no
# Step: 260 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 261 | Predicted movie_id: 57243 | reward: 3.5
# eval_mode: no
# Step: 262 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 263 | Predicted movie_id: 6789 | reward: 4.0
# eval_mode: no
# Step: 264 | Predicted movie_id: 26225 | reward: 4.5
# eval_mode: no
# Step: 265 | Predicted movie_id: 7349 | reward: 3.0
# eval_mode: no
# Step: 266 | Predicted movie_id: 31410 | reward: 4.0
# eval_mode: no
# Step: 267 | Predicted movie_id: 52042 | reward: 2.5
# eval_mode: no
# Step: 268 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 269 | Predicted movie_id: 120637 | reward: 2.5
# eval_mode: no
# Step: 270 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 271 | Predicted movie_id: 4296 | reward: 3.0
# eval_mode: no
# Step: 272 | Predicted movie_id: 27815 | reward: 4.0
# eval_mode: no
# Step: 273 | Predicted movie_id: 168712 | reward: 1.0
# eval_mode: no
# Step: 274 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 275 | Predicted movie_id: 307 | reward: 4.0
# eval_mode: no
# Step: 276 | Predicted movie_id: 2686 | reward: 4.0
# eval_mode: no
# Step: 277 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 278 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 279 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 280 | Predicted movie_id: 2696 | reward: 4.5
# eval_mode: no
# Step: 281 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 282 | Predicted movie_id: 6893 | reward: 4.0
# eval_mode: no
# Step: 283 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 284 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 285 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 286 | Predicted movie_id: 1812 | reward: 3.5
# eval_mode: no
# Step: 287 | Predicted movie_id: 162 | reward: 4.0
# eval_mode: no
# Step: 288 | Predicted movie_id: 2544 | reward: 3.0
# eval_mode: no
# Step: 289 | Predicted movie_id: 161024 | reward: 4.5
# eval_mode: no
# Step: 290 | Predicted movie_id: 26048 | reward: 4.5
# eval_mode: no
# Step: 291 | Predicted movie_id: 64620 | reward: 4.0
# eval_mode: no
# Step: 292 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 293 | Predicted movie_id: 484 | reward: 3.0
# eval_mode: no
# Step: 294 | Predicted movie_id: 6973 | reward: 2.5
# eval_mode: no
# Step: 295 | Predicted movie_id: 27664 | reward: 3.0
# eval_mode: no
# Step: 296 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 297 | Predicted movie_id: 131749 | reward: 3.0
# eval_mode: no
# Step: 298 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 299 | Predicted movie_id: 8128 | reward: 4.0
# eval_mode: no
# Step: 300 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 301 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 302 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 303 | Predicted movie_id: 3053 | reward: 4.0
# eval_mode: no
# Step: 304 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 305 | Predicted movie_id: 8239 | reward: 4.0
# eval_mode: no
# Step: 306 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 307 | Predicted movie_id: 31522 | reward: 5.0
# eval_mode: no
# Step: 308 | Predicted movie_id: 886 | reward: 2.5
# eval_mode: no
# Step: 309 | Predicted movie_id: 31410 | reward: 4.0
# eval_mode: no
# Step: 310 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 311 | Predicted movie_id: 80590 | reward: 3.0
# eval_mode: no
# Step: 312 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 313 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 314 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 315 | Predicted movie_id: 65651 | reward: 2.0
# eval_mode: no
# Step: 316 | Predicted movie_id: 26940 | reward: 2.5
# eval_mode: no
# Step: 317 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 318 | Predicted movie_id: 73858 | reward: 1.5
# eval_mode: no
# Step: 319 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 320 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 321 | Predicted movie_id: 129354 | reward: 3.0
# eval_mode: no
# Step: 322 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 323 | Predicted movie_id: 2669 | reward: 3.5
# eval_mode: no
# Step: 324 | Predicted movie_id: 94150 | reward: 4.0
# eval_mode: no
# Step: 325 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 326 | Predicted movie_id: 1307 | reward: 4.0
# eval_mode: no
# Step: 327 | Predicted movie_id: 5993 | reward: 3.0
# eval_mode: no
# Step: 328 | Predicted movie_id: 6299 | reward: 3.5
# eval_mode: no
# Step: 329 | Predicted movie_id: 32875 | reward: 3.0
# eval_mode: no
# Step: 330 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 331 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 332 | Predicted movie_id: 4345 | reward: 4.0
# eval_mode: no
# Step: 333 | Predicted movie_id: 8677 | reward: 1.0
# eval_mode: no
# Step: 334 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 335 | Predicted movie_id: 2686 | reward: 4.0
# eval_mode: no
# Step: 336 | Predicted movie_id: 59810 | reward: 3.5
# eval_mode: no
# Step: 337 | Predicted movie_id: 3158 | reward: 3.5
# eval_mode: no
# Step: 338 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 339 | Predicted movie_id: 73017 | reward: 3.5
# eval_mode: no
# Step: 340 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 341 | Predicted movie_id: 6041 | reward: 4.0
# eval_mode: no
# Step: 342 | Predicted movie_id: 1237 | reward: 4.0
# eval_mode: no
# Step: 343 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 344 | Predicted movie_id: 27815 | reward: 4.0
# eval_mode: no
# Step: 345 | Predicted movie_id: 91671 | reward: 1.0
# eval_mode: no
# Step: 346 | Predicted movie_id: 4736 | reward: 2.5
# eval_mode: no
# Step: 347 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 348 | Predicted movie_id: 3637 | reward: 5.0
# eval_mode: no
# Step: 349 | Predicted movie_id: 140 | reward: 3.5
# eval_mode: no
# Step: 350 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 351 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 352 | Predicted movie_id: 26073 | reward: 5.0
# eval_mode: no
# Step: 353 | Predicted movie_id: 4957 | reward: 3.5
# eval_mode: no
# Step: 354 | Predicted movie_id: 2742 | reward: 1.0
# eval_mode: no
# Step: 355 | Predicted movie_id: 56152 | reward: 4.5
# eval_mode: no
# Step: 356 | Predicted movie_id: 141513 | reward: 4.0
# eval_mode: no
# Step: 357 | Predicted movie_id: 6386 | reward: 4.0
# eval_mode: no
# Step: 358 | Predicted movie_id: 3889 | reward: 2.0
# eval_mode: no
# Step: 359 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 360 | Predicted movie_id: 3173 | reward: 3.0
# eval_mode: no
# Step: 361 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 362 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 363 | Predicted movie_id: 1964 | reward: 4.0
# eval_mode: no
# Step: 364 | Predicted movie_id: 144262 | reward: 2.0
# eval_mode: no
# Step: 365 | Predicted movie_id: 3747 | reward: 3.5
# eval_mode: no
# Step: 366 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 367 | Predicted movie_id: 104644 | reward: 0.5
# eval_mode: no
# Step: 368 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 369 | Predicted movie_id: 148166 | reward: 3.5
# eval_mode: no
# Step: 370 | Predicted movie_id: 8804 | reward: 5.0
# eval_mode: no
# Step: 371 | Predicted movie_id: 3088 | reward: 4.0
# eval_mode: no
# Step: 372 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 373 | Predicted movie_id: 58156 | reward: 3.0
# eval_mode: no
# Step: 374 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 375 | Predicted movie_id: 26225 | reward: 4.5
# eval_mode: no
# Step: 376 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 377 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 378 | Predicted movie_id: 331 | reward: 3.0
# eval_mode: no
# Step: 379 | Predicted movie_id: 100714 | reward: 3.5
# eval_mode: no
# Step: 380 | Predicted movie_id: 129354 | reward: 3.0
# eval_mode: no
# Step: 381 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 382 | Predicted movie_id: 3855 | reward: 5.0
# eval_mode: no
# Step: 383 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 384 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 385 | Predicted movie_id: 2374 | reward: 3.0
# eval_mode: no
# Step: 386 | Predicted movie_id: 52579 | reward: 3.0
# eval_mode: no
# Step: 387 | Predicted movie_id: 97188 | reward: 4.0
# eval_mode: no
# Step: 388 | Predicted movie_id: 51082 | reward: 2.0
# eval_mode: no
# Step: 389 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 390 | Predicted movie_id: 84716 | reward: 4.0
# eval_mode: no
# Step: 391 | Predicted movie_id: 110611 | reward: 2.5
# eval_mode: no
# Step: 392 | Predicted movie_id: 54734 | reward: 2.5
# eval_mode: no
# Step: 393 | Predicted movie_id: 44943 | reward: 5.0
# eval_mode: no
# Step: 394 | Predicted movie_id: 100507 | reward: 3.5
# eval_mode: no
# Step: 395 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 396 | Predicted movie_id: 7041 | reward: 2.5
# eval_mode: no
# Step: 397 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 398 | Predicted movie_id: 5896 | reward: 4.0
# eval_mode: no
# Step: 399 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 400 | Predicted movie_id: 6985 | reward: 4.0
# eval_mode: no
# Step: 401 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 402 | Predicted movie_id: 3221 | reward: 3.5
# eval_mode: no
# Step: 403 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 404 | Predicted movie_id: 84716 | reward: 4.0
# eval_mode: no
# Step: 405 | Predicted movie_id: 121129 | reward: 2.5
# eval_mode: no
# Step: 406 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 407 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 408 | Predicted movie_id: 148166 | reward: 3.5
# eval_mode: no
# Step: 409 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 410 | Predicted movie_id: 6985 | reward: 4.0
# eval_mode: no
# Step: 411 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 412 | Predicted movie_id: 8128 | reward: 4.0
# eval_mode: no
# Step: 413 | Predicted movie_id: 95839 | reward: 3.0
# eval_mode: no
# Step: 414 | Predicted movie_id: 168026 | reward: 4.0
# eval_mode: no
# Step: 415 | Predicted movie_id: 73804 | reward: 4.0
# eval_mode: no
# Step: 416 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 417 | Predicted movie_id: 5993 | reward: 3.0
# eval_mode: no
# Step: 418 | Predicted movie_id: 2445 | reward: 2.5
# eval_mode: no
# Step: 419 | Predicted movie_id: 7700 | reward: 3.5
# eval_mode: no
# Step: 420 | Predicted movie_id: 26940 | reward: 2.5
# eval_mode: no
# Step: 421 | Predicted movie_id: 109161 | reward: 4.5
# eval_mode: no
# Step: 422 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 423 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 424 | Predicted movie_id: 190221 | reward: 1.0
# eval_mode: no
# Step: 425 | Predicted movie_id: 140267 | reward: 4.0
# eval_mode: no
# Step: 426 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 427 | Predicted movie_id: 81562 | reward: 4.0
# eval_mode: no
# Step: 428 | Predicted movie_id: 134109 | reward: 5.0
# eval_mode: no
# Step: 429 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 430 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 431 | Predicted movie_id: 8677 | reward: 1.0
# eval_mode: no
# Step: 432 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 433 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 434 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 435 | Predicted movie_id: 54276 | reward: 3.0
# eval_mode: no
# Step: 436 | Predicted movie_id: 4008 | reward: 3.5
# eval_mode: no
# Step: 437 | Predicted movie_id: 74795 | reward: 3.5
# eval_mode: no
# Step: 438 | Predicted movie_id: 168712 | reward: 1.0
# eval_mode: no
# Step: 439 | Predicted movie_id: 4623 | reward: 3.5
# eval_mode: no
# Step: 440 | Predicted movie_id: 79185 | reward: 3.5
# eval_mode: no
# Step: 441 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 442 | Predicted movie_id: 99437 | reward: 4.0
# eval_mode: no
# Step: 443 | Predicted movie_id: 107069 | reward: 3.0
# eval_mode: no
# Step: 444 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 445 | Predicted movie_id: 263 | reward: 4.0
# eval_mode: no
# Step: 446 | Predicted movie_id: 1526 | reward: 1.0
# eval_mode: no
# Step: 447 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 448 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 449 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 450 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 451 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 452 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 453 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 454 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 455 | Predicted movie_id: 285 | reward: 4.0
# eval_mode: no
# Step: 456 | Predicted movie_id: 246 | reward: 4.5
# eval_mode: no
# Step: 457 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 458 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 459 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 460 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 461 | Predicted movie_id: 65261 | reward: 4.0
# eval_mode: no
# Step: 462 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 463 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 464 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 465 | Predicted movie_id: 32875 | reward: 3.0
# eval_mode: no
# Step: 466 | Predicted movie_id: 6993 | reward: 4.0
# eval_mode: no
# Step: 467 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 468 | Predicted movie_id: 26048 | reward: 4.5
# eval_mode: no
# Step: 469 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 470 | Predicted movie_id: 6055 | reward: 2.0
# eval_mode: no
# Step: 471 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 472 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 473 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 474 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 475 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 476 | Predicted movie_id: 139640 | reward: 5.0
# eval_mode: no
# Step: 477 | Predicted movie_id: 1447 | reward: 3.5
# eval_mode: no
# Step: 478 | Predicted movie_id: 116169 | reward: 2.5
# eval_mode: no
# Step: 479 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 480 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 481 | Predicted movie_id: 179709 | reward: 3.0
# eval_mode: no
# Step: 482 | Predicted movie_id: 95744 | reward: 2.5
# eval_mode: no
# Step: 483 | Predicted movie_id: 96829 | reward: 4.5
# eval_mode: no
# Step: 484 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 485 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 486 | Predicted movie_id: 213 | reward: 4.0
# eval_mode: no
# Step: 487 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 488 | Predicted movie_id: 175401 | reward: 4.0
# eval_mode: no
# Step: 489 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 490 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 491 | Predicted movie_id: 3274 | reward: 3.5
# eval_mode: no
# Step: 492 | Predicted movie_id: 66198 | reward: 3.0
# eval_mode: no
# Step: 493 | Predicted movie_id: 71867 | reward: 3.0
# eval_mode: no
# Step: 494 | Predicted movie_id: 55553 | reward: 2.5
# eval_mode: no
# Step: 495 | Predicted movie_id: 3641 | reward: 4.0
# eval_mode: no
# Step: 496 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 497 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 498 | Predicted movie_id: 6579 | reward: 4.0
# eval_mode: no
# Step: 499 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 500 | Predicted movie_id: 6818 | reward: 5.0
# eval_mode: no
# Step: 501 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 502 | Predicted movie_id: 8228 | reward: 3.5
# eval_mode: no
# Step: 503 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 504 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 505 | Predicted movie_id: 6186 | reward: 3.0
# eval_mode: no
# Step: 506 | Predicted movie_id: 8261 | reward: 4.0
# eval_mode: no
# Step: 507 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 508 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 509 | Predicted movie_id: 59727 | reward: 3.0
# eval_mode: no
# Step: 510 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 511 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 512 | Predicted movie_id: 31150 | reward: 2.0
# eval_mode: no
# Step: 513 | Predicted movie_id: 55492 | reward: 4.0
# eval_mode: no
# Step: 514 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 515 | Predicted movie_id: 7745 | reward: 4.0
# eval_mode: no
# Step: 516 | Predicted movie_id: 8951 | reward: 3.0
# eval_mode: no
# Step: 517 | Predicted movie_id: 69654 | reward: 3.5
# eval_mode: no
# Step: 518 | Predicted movie_id: 190221 | reward: 1.0
# eval_mode: no
# Step: 519 | Predicted movie_id: 91860 | reward: 4.0
# eval_mode: no
# Step: 520 | Predicted movie_id: 31431 | reward: 1.5
# eval_mode: no
# Step: 521 | Predicted movie_id: 4992 | reward: 3.0
# eval_mode: no
# Step: 522 | Predicted movie_id: 4008 | reward: 3.5
# eval_mode: no
# Step: 523 | Predicted movie_id: 55814 | reward: 4.0
# eval_mode: no
# Step: 524 | Predicted movie_id: 109161 | reward: 4.5
# eval_mode: no
# Step: 525 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 526 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 527 | Predicted movie_id: 56060 | reward: 4.5
# eval_mode: no
# Step: 528 | Predicted movie_id: 107723 | reward: 3.0
# eval_mode: no
# Step: 529 | Predicted movie_id: 57243 | reward: 3.0
# eval_mode: no
# Step: 530 | Predicted movie_id: 2044 | reward: 2.5
# eval_mode: no
# Step: 531 | Predicted movie_id: 948 | reward: 4.0
# eval_mode: no
# Step: 532 | Predicted movie_id: 128099 | reward: 4.5
# eval_mode: no
# Step: 533 | Predicted movie_id: 41712 | reward: 4.0
# eval_mode: no
# Step: 534 | Predicted movie_id: 377 | reward: 3.5
# eval_mode: no
# Step: 535 | Predicted movie_id: 99191 | reward: 4.0
# eval_mode: no
# Step: 536 | Predicted movie_id: 3719 | reward: 3.0
# eval_mode: no
# Step: 537 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 538 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 539 | Predicted movie_id: 7093 | reward: 4.0
# eval_mode: no
# Step: 540 | Predicted movie_id: 70946 | reward: 3.5
# eval_mode: no
# Step: 541 | Predicted movie_id: 41285 | reward: 3.5
# eval_mode: no
# Step: 542 | Predicted movie_id: 54617 | reward: 3.5
# eval_mode: no
# Step: 543 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 544 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 545 | Predicted movie_id: 1177 | reward: 4.0
# eval_mode: no
# Step: 546 | Predicted movie_id: 159510 | reward: 2.0
# eval_mode: no
# Step: 547 | Predicted movie_id: 58156 | reward: 3.0
# eval_mode: no
# Step: 548 | Predicted movie_id: 37380 | reward: 2.0
# eval_mode: no
# Step: 549 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 550 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 551 | Predicted movie_id: 59429 | reward: 3.0
# eval_mode: no
# Step: 552 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 553 | Predicted movie_id: 6588 | reward: 4.0
# eval_mode: no
# Step: 554 | Predicted movie_id: 27563 | reward: 4.5
# eval_mode: no
# Step: 555 | Predicted movie_id: 1955 | reward: 4.0
# eval_mode: no
# Step: 556 | Predicted movie_id: 190221 | reward: 1.0
# eval_mode: no
# Step: 557 | Predicted movie_id: 79798 | reward: 3.5
# eval_mode: no
# Step: 558 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 559 | Predicted movie_id: 80094 | reward: 4.0
# eval_mode: no
# Step: 560 | Predicted movie_id: 8804 | reward: 5.0
# eval_mode: no
# Step: 561 | Predicted movie_id: 117109 | reward: 3.0
# eval_mode: no
# Step: 562 | Predicted movie_id: 6214 | reward: 4.0
# eval_mode: no
# Step: 563 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 564 | Predicted movie_id: 1227 | reward: 4.0
# eval_mode: no
# Step: 565 | Predicted movie_id: 101072 | reward: 2.5
# eval_mode: no
# Step: 566 | Predicted movie_id: 93510 | reward: 4.0
# eval_mode: no
# Step: 567 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 568 | Predicted movie_id: 89582 | reward: 4.5
# eval_mode: no
# Step: 569 | Predicted movie_id: 81786 | reward: 4.0
# eval_mode: no
# Step: 570 | Predicted movie_id: 138210 | reward: 3.5
# eval_mode: no
# Step: 571 | Predicted movie_id: 37384 | reward: 3.5
# eval_mode: no
# Step: 572 | Predicted movie_id: 1117 | reward: 3.5
# eval_mode: no
# Step: 573 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 574 | Predicted movie_id: 127298 | reward: 4.0
# eval_mode: no
# Step: 575 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 576 | Predicted movie_id: 8933 | reward: 4.0
# eval_mode: no
# Step: 577 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 578 | Predicted movie_id: 5955 | reward: 3.5
# eval_mode: no
# Step: 579 | Predicted movie_id: 2794 | reward: 2.5
# eval_mode: no
# Step: 580 | Predicted movie_id: 93819 | reward: 3.5
# eval_mode: no
# Step: 581 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 582 | Predicted movie_id: 8946 | reward: 2.5
# eval_mode: no
# Step: 583 | Predicted movie_id: 4345 | reward: 4.0
# eval_mode: no
# Step: 584 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 585 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 586 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 587 | Predicted movie_id: 1572 | reward: 3.0
# eval_mode: no
# Step: 588 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 589 | Predicted movie_id: 140267 | reward: 4.0
# eval_mode: no
# Step: 590 | Predicted movie_id: 83134 | reward: 4.0
# eval_mode: no
# Step: 591 | Predicted movie_id: 178615 | reward: 3.5
# eval_mode: no
# Step: 592 | Predicted movie_id: 4677 | reward: 3.0
# eval_mode: no
# Step: 593 | Predicted movie_id: 2044 | reward: 2.5
# eval_mode: no
# Step: 594 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 595 | Predicted movie_id: 3258 | reward: 3.0
# eval_mode: no
# Step: 596 | Predicted movie_id: 6386 | reward: 4.0
# eval_mode: no
# Step: 597 | Predicted movie_id: 162982 | reward: 3.0
# eval_mode: no
# Step: 598 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 599 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 600 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 601 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 602 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 603 | Predicted movie_id: 149334 | reward: 3.0
# eval_mode: no
# Step: 604 | Predicted movie_id: 1747 | reward: 3.5
# eval_mode: no
# Step: 605 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 606 | Predicted movie_id: 70703 | reward: 2.0
# eval_mode: no
# Step: 607 | Predicted movie_id: 26761 | reward: 3.0
# eval_mode: no
# Step: 608 | Predicted movie_id: 1021 | reward: 2.5
# eval_mode: no
# Step: 609 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 610 | Predicted movie_id: 103372 | reward: 3.5
# eval_mode: no
# Step: 611 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 612 | Predicted movie_id: 90357 | reward: 3.5
# eval_mode: no
# Step: 613 | Predicted movie_id: 4677 | reward: 3.0
# eval_mode: no
# Step: 614 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 615 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 616 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 617 | Predicted movie_id: 484 | reward: 3.0
# eval_mode: no
# Step: 618 | Predicted movie_id: 2064 | reward: 4.0
# eval_mode: no
# Step: 619 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 620 | Predicted movie_id: 4193 | reward: 4.0
# eval_mode: no
# Step: 621 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 622 | Predicted movie_id: 26073 | reward: 5.0
# eval_mode: no
# Step: 623 | Predicted movie_id: 178615 | reward: 3.5
# eval_mode: no
# Step: 624 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 625 | Predicted movie_id: 158388 | reward: 2.5
# eval_mode: no
# Step: 626 | Predicted movie_id: 6429 | reward: 4.0
# eval_mode: no
# Step: 627 | Predicted movie_id: 1192 | reward: 4.5
# eval_mode: no
# Step: 628 | Predicted movie_id: 26940 | reward: 2.5
# eval_mode: no
# Step: 629 | Predicted movie_id: 43376 | reward: 4.5
# eval_mode: no
# Step: 630 | Predicted movie_id: 54796 | reward: 3.5
# eval_mode: no
# Step: 631 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 632 | Predicted movie_id: 65225 | reward: 4.5
# eval_mode: no
# Step: 633 | Predicted movie_id: 91860 | reward: 4.0
# eval_mode: no
# Step: 634 | Predicted movie_id: 8622 | reward: 4.0
# eval_mode: no
# Step: 635 | Predicted movie_id: 2686 | reward: 4.0
# eval_mode: no
# Step: 636 | Predicted movie_id: 5458 | reward: 2.5
# eval_mode: no
# Step: 637 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 638 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 639 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 640 | Predicted movie_id: 4154 | reward: 4.0
# eval_mode: no
# Step: 641 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 642 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 643 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 644 | Predicted movie_id: 142456 | reward: 4.0
# eval_mode: no
# Step: 645 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 646 | Predicted movie_id: 3186 | reward: 3.5
# eval_mode: no
# Step: 647 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 648 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 649 | Predicted movie_id: 4465 | reward: 3.5
# eval_mode: no
# Step: 650 | Predicted movie_id: 1171 | reward: 3.5
# eval_mode: no
# Step: 651 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 652 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 653 | Predicted movie_id: 263 | reward: 4.0
# eval_mode: no
# Step: 654 | Predicted movie_id: 6299 | reward: 3.5
# eval_mode: no
# Step: 655 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 656 | Predicted movie_id: 170401 | reward: 3.0
# eval_mode: no
# Step: 657 | Predicted movie_id: 27899 | reward: 3.0
# eval_mode: no
# Step: 658 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 659 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 660 | Predicted movie_id: 114627 | reward: 3.0
# eval_mode: no
# Step: 661 | Predicted movie_id: 4482 | reward: 3.0
# eval_mode: no
# Step: 662 | Predicted movie_id: 39446 | reward: 4.0
# eval_mode: no
# Step: 663 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 664 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 665 | Predicted movie_id: 6811 | reward: 2.5
# eval_mode: no
# Step: 666 | Predicted movie_id: 6123 | reward: 4.0
# eval_mode: no
# Step: 667 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 668 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 669 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 670 | Predicted movie_id: 54617 | reward: 3.5
# eval_mode: no
# Step: 671 | Predicted movie_id: 95475 | reward: 4.0
# eval_mode: no
# Step: 672 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 673 | Predicted movie_id: 3955 | reward: 1.5
# eval_mode: no
# Step: 674 | Predicted movie_id: 7831 | reward: 3.5
# eval_mode: no
# Step: 675 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 676 | Predicted movie_id: 175401 | reward: 4.0
# eval_mode: no
# Step: 677 | Predicted movie_id: 1969 | reward: 2.5
# eval_mode: no
# Step: 678 | Predicted movie_id: 2534 | reward: 2.5
# eval_mode: no
# Step: 679 | Predicted movie_id: 3893 | reward: 3.5
# eval_mode: no
# Step: 680 | Predicted movie_id: 168712 | reward: 1.0
# eval_mode: no
# Step: 681 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 682 | Predicted movie_id: 2360 | reward: 4.5
# eval_mode: no
# Step: 683 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 684 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 685 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 686 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 687 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 688 | Predicted movie_id: 81383 | reward: 2.5
# eval_mode: no
# Step: 689 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 690 | Predicted movie_id: 57243 | reward: 3.0
# eval_mode: no
# Step: 691 | Predicted movie_id: 91628 | reward: 2.0
# eval_mode: no
# Step: 692 | Predicted movie_id: 89582 | reward: 4.5
# eval_mode: no
# Step: 693 | Predicted movie_id: 46574 | reward: 2.5
# eval_mode: no
# Step: 694 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 695 | Predicted movie_id: 84772 | reward: 3.0
# eval_mode: no
# Step: 696 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 697 | Predicted movie_id: 1161 | reward: 3.5
# eval_mode: no
# Step: 698 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 699 | Predicted movie_id: 101072 | reward: 2.5
# eval_mode: no
# Step: 700 | Predicted movie_id: 1237 | reward: 4.0
# eval_mode: no
# Step: 701 | Predicted movie_id: 70 | reward: 3.5
# eval_mode: no
# Step: 702 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 703 | Predicted movie_id: 70984 | reward: 3.0
# eval_mode: no
# Step: 704 | Predicted movie_id: 1116 | reward: 4.0
# eval_mode: no
# Step: 705 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 706 | Predicted movie_id: 89427 | reward: 1.5
# eval_mode: no
# Step: 707 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 708 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 709 | Predicted movie_id: 4809 | reward: 4.0
# eval_mode: no
# Step: 710 | Predicted movie_id: 307 | reward: 4.0
# eval_mode: no
# Step: 711 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 712 | Predicted movie_id: 190221 | reward: 1.0
# eval_mode: no
# Step: 713 | Predicted movie_id: 7349 | reward: 3.0
# eval_mode: no
# Step: 714 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 715 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 716 | Predicted movie_id: 62644 | reward: 3.5
# eval_mode: no
# Step: 717 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 718 | Predicted movie_id: 4677 | reward: 3.0
# eval_mode: no
# Step: 719 | Predicted movie_id: 3142 | reward: 3.0
# eval_mode: no
# Step: 720 | Predicted movie_id: 3372 | reward: 4.0
# eval_mode: no
# Step: 721 | Predicted movie_id: 4663 | reward: 3.0
# eval_mode: no
# Step: 722 | Predicted movie_id: 2107 | reward: 3.0
# eval_mode: no
# Step: 723 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 724 | Predicted movie_id: 1284 | reward: 4.0
# eval_mode: no
# Step: 725 | Predicted movie_id: 6237 | reward: 4.0
# eval_mode: no
# Step: 726 | Predicted movie_id: 89864 | reward: 3.5
# eval_mode: no
# Step: 727 | Predicted movie_id: 129354 | reward: 3.0
# eval_mode: no
# Step: 728 | Predicted movie_id: 59429 | reward: 3.0
# eval_mode: no
# Step: 729 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 730 | Predicted movie_id: 1747 | reward: 3.5
# eval_mode: no
# Step: 731 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 732 | Predicted movie_id: 167036 | reward: 4.0
# ...
# Step: 1813 | Predicted movie_id: 190221 | reward: 1.0
# eval_mode: no
# Step: 1814 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 1815 | Predicted movie_id: 55205 | reward: 2.5
# eval_mode: no
# Step: 1816 | Predicted movie_id: 3182 | reward: 4.0
# eval_mode: no
# Step: 1817 | Predicted movie_id: 6702 | reward: 2.5
# eval_mode: no
# Step: 1818 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 1819 | Predicted movie_id: 3893 | reward: 3.5
# eval_mode: no
# Step: 1820 | Predicted movie_id: 107565 | reward: 3.0
# eval_mode: no
# Step: 1821 | Predicted movie_id: 3574 | reward: 1.0
# eval_mode: no
# Step: 1822 | Predicted movie_id: 6553 | reward: 4.0
# eval_mode: no
# Step: 1823 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 1824 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 1825 | Predicted movie_id: 57243 | reward: 3.5
# eval_mode: no
# Step: 1826 | Predicted movie_id: 44943 | reward: 5.0
# eval_mode: no
# Step: 1827 | Predicted movie_id: 823 | reward: 3.5
# eval_mode: no
# Step: 1828 | Predicted movie_id: 4623 | reward: 3.5
# eval_mode: no
# Step: 1829 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 1830 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 1831 | Predicted movie_id: 40629 | reward: 3.5
# eval_mode: no
# Step: 1832 | Predicted movie_id: 6811 | reward: 2.5
# eval_mode: no
# Step: 1833 | Predicted movie_id: 47099 | reward: 4.0
# eval_mode: no
# Step: 1834 | Predicted movie_id: 461 | reward: 3.0
# eval_mode: no
# Step: 1835 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 1836 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 1837 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 1838 | Predicted movie_id: 484 | reward: 3.0
# eval_mode: no
# Step: 1839 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 1840 | Predicted movie_id: 71438 | reward: 1.0
# eval_mode: no
# Step: 1841 | Predicted movie_id: 938 | reward: 3.0
# eval_mode: no
# Step: 1842 | Predicted movie_id: 106889 | reward: 4.0
# eval_mode: no
# Step: 1843 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 1844 | Predicted movie_id: 4349 | reward: 4.0
# eval_mode: no
# Step: 1845 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 1846 | Predicted movie_id: 1574 | reward: 1.0
# eval_mode: no
# Step: 1847 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 1848 | Predicted movie_id: 4677 | reward: 3.0
# eval_mode: no
# Step: 1849 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 1850 | Predicted movie_id: 2700 | reward: 4.0
# eval_mode: no
# Step: 1851 | Predicted movie_id: 64620 | reward: 4.0
# eval_mode: no
# Step: 1852 | Predicted movie_id: 170897 | reward: 2.0
# eval_mode: no
# Step: 1853 | Predicted movie_id: 51498 | reward: 3.0
# eval_mode: no
# Step: 1854 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 1855 | Predicted movie_id: 2174 | reward: 4.0
# eval_mode: no
# Step: 1856 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 1857 | Predicted movie_id: 51933 | reward: 2.5
# eval_mode: no
# Step: 1858 | Predicted movie_id: 26940 | reward: 2.5
# eval_mode: no
# Step: 1859 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 1860 | Predicted movie_id: 5618 | reward: 4.0
# eval_mode: no
# Step: 1861 | Predicted movie_id: 5041 | reward: 1.5
# eval_mode: no
# Step: 1862 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 1863 | Predicted movie_id: 93134 | reward: 3.5
# eval_mode: no
# Step: 1864 | Predicted movie_id: 175401 | reward: 4.0
# eval_mode: no
# Step: 1865 | Predicted movie_id: 8677 | reward: 1.0
# eval_mode: no
# Step: 1866 | Predicted movie_id: 70703 | reward: 2.0
# eval_mode: no
# Step: 1867 | Predicted movie_id: 307 | reward: 4.0
# eval_mode: no
# Step: 1868 | Predicted movie_id: 26870 | reward: 2.5
# eval_mode: no
# Step: 1869 | Predicted movie_id: 95497 | reward: 4.0
# eval_mode: no
# Step: 1870 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 1871 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 1872 | Predicted movie_id: 90357 | reward: 3.5
# eval_mode: no
# Step: 1873 | Predicted movie_id: 54276 | reward: 3.0
# eval_mode: no
# Step: 1874 | Predicted movie_id: 142598 | reward: 4.0
# eval_mode: no
# Step: 1875 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 1876 | Predicted movie_id: 163981 | reward: 3.5
# eval_mode: no
# Step: 1877 | Predicted movie_id: 136471 | reward: 3.5
# eval_mode: no
# Step: 1878 | Predicted movie_id: 122926 | reward: 4.0
# eval_mode: no
# Step: 1879 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 1880 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 1881 | Predicted movie_id: 26940 | reward: 2.5
# eval_mode: no
# Step: 1882 | Predicted movie_id: 4380 | reward: 4.0
# eval_mode: no
# Step: 1883 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 1884 | Predicted movie_id: 26225 | reward: 4.5
# eval_mode: no
# Step: 1885 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 1886 | Predicted movie_id: 41569 | reward: 3.5
# eval_mode: no
# Step: 1887 | Predicted movie_id: 8690 | reward: 4.0
# eval_mode: no
# Step: 1888 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 1889 | Predicted movie_id: 824 | reward: 4.0
# eval_mode: no
# Step: 1890 | Predicted movie_id: 38304 | reward: 4.5
# eval_mode: no
# Step: 1891 | Predicted movie_id: 82242 | reward: 4.0
# eval_mode: no
# Step: 1892 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 1893 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 1894 | Predicted movie_id: 71867 | reward: 3.0
# eval_mode: no
# Step: 1895 | Predicted movie_id: 5363 | reward: 2.5
# eval_mode: no
# Step: 1896 | Predicted movie_id: 1526 | reward: 1.0
# eval_mode: no
# Step: 1897 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 1898 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 1899 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 1900 | Predicted movie_id: 3254 | reward: 2.0
# eval_mode: no
# Step: 1901 | Predicted movie_id: 53574 | reward: 4.0
# eval_mode: no
# Step: 1902 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 1903 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 1904 | Predicted movie_id: 101072 | reward: 2.5
# eval_mode: no
# Step: 1905 | Predicted movie_id: 3633 | reward: 3.5
# eval_mode: no
# Step: 1906 | Predicted movie_id: 766 | reward: 3.5
# eval_mode: no
# Step: 1907 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 1908 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 1909 | Predicted movie_id: 4992 | reward: 3.0
# eval_mode: no
# Step: 1910 | Predicted movie_id: 3417 | reward: 3.0
# eval_mode: no
# Step: 1911 | Predicted movie_id: 5971 | reward: 4.0
# eval_mode: no
# Step: 1912 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 1913 | Predicted movie_id: 80478 | reward: 4.0
# eval_mode: no
# Step: 1914 | Predicted movie_id: 5984 | reward: 3.5
# eval_mode: no
# Step: 1915 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 1916 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 1917 | Predicted movie_id: 6666 | reward: 4.5
# eval_mode: no
# Step: 1918 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 1919 | Predicted movie_id: 4612 | reward: 4.5
# eval_mode: no
# Step: 1920 | Predicted movie_id: 3855 | reward: 5.0
# eval_mode: no
# Step: 1921 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 1922 | Predicted movie_id: 4677 | reward: 3.0
# eval_mode: no
# Step: 1923 | Predicted movie_id: 4630 | reward: 1.0
# eval_mode: no
# Step: 1924 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 1925 | Predicted movie_id: 8622 | reward: 3.5
# eval_mode: no
# Step: 1926 | Predicted movie_id: 2414 | reward: 3.0
# eval_mode: no
# Step: 1927 | Predicted movie_id: 109864 | reward: 2.0
# eval_mode: no
# Step: 1928 | Predicted movie_id: 31150 | reward: 2.0
# eval_mode: no
# Step: 1929 | Predicted movie_id: 4973 | reward: 4.0
# eval_mode: no
# Step: 1930 | Predicted movie_id: 2445 | reward: 2.5
# eval_mode: no
# Step: 1931 | Predicted movie_id: 71910 | reward: 2.5
# eval_mode: no
# Step: 1932 | Predicted movie_id: 1461 | reward: 3.0
# eval_mode: no
# Step: 1933 | Predicted movie_id: 79185 | reward: 3.5
# eval_mode: no
# Step: 1934 | Predicted movie_id: 4127 | reward: 1.5
# eval_mode: no
# Step: 1935 | Predicted movie_id: 31522 | reward: 5.0
# eval_mode: no
# Step: 1936 | Predicted movie_id: 176371 | reward: 4.0
# eval_mode: no
# Step: 1937 | Predicted movie_id: 586 | reward: 3.0
# eval_mode: no
# Step: 1938 | Predicted movie_id: 117109 | reward: 3.0
# eval_mode: no
# Step: 1939 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 1940 | Predicted movie_id: 2813 | reward: 1.0
# eval_mode: no
# Step: 1941 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 1942 | Predicted movie_id: 2044 | reward: 3.0
# eval_mode: no
# Step: 1943 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 1944 | Predicted movie_id: 3258 | reward: 2.0
# eval_mode: no
# Step: 1945 | Predicted movie_id: 3637 | reward: 5.0
# eval_mode: no
# Step: 1946 | Predicted movie_id: 2544 | reward: 3.0
# eval_mode: no
# Step: 1947 | Predicted movie_id: 79798 | reward: 3.5
# eval_mode: no
# Step: 1948 | Predicted movie_id: 2081 | reward: 4.0
# eval_mode: no
# Step: 1949 | Predicted movie_id: 46965 | reward: 2.5
# eval_mode: no
# Step: 1950 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 1951 | Predicted movie_id: 2518 | reward: 2.0
# eval_mode: no
# Step: 1952 | Predicted movie_id: 26797 | reward: 3.0
# eval_mode: no
# Step: 1953 | Predicted movie_id: 190207 | reward: 1.5
# eval_mode: no
# Step: 1954 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 1955 | Predicted movie_id: 26761 | reward: 3.0
# eval_mode: no
# Step: 1956 | Predicted movie_id: 7745 | reward: 4.0
# eval_mode: no
# Step: 1957 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 1958 | Predicted movie_id: 3633 | reward: 3.5
# eval_mode: no
# Step: 1959 | Predicted movie_id: 132488 | reward: 2.0
# eval_mode: no
# Step: 1960 | Predicted movie_id: 74668 | reward: 4.0
# eval_mode: no
# Step: 1961 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 1962 | Predicted movie_id: 86347 | reward: 3.5
# eval_mode: no
# Step: 1963 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 1964 | Predicted movie_id: 1461 | reward: 3.0
# eval_mode: no
# Step: 1965 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 1966 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 1967 | Predicted movie_id: 7925 | reward: 4.0
# eval_mode: no
# Step: 1968 | Predicted movie_id: 4677 | reward: 3.0
# eval_mode: no
# Step: 1969 | Predicted movie_id: 100507 | reward: 3.5
# eval_mode: no
# Step: 1970 | Predicted movie_id: 128832 | reward: 3.5
# eval_mode: no
# Step: 1971 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 1972 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 1973 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 1974 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 1975 | Predicted movie_id: 34148 | reward: 3.0
# eval_mode: no
# Step: 1976 | Predicted movie_id: 484 | reward: 3.0
# eval_mode: no
# Step: 1977 | Predicted movie_id: 2188 | reward: 2.0
# eval_mode: no
# Step: 1978 | Predicted movie_id: 3515 | reward: 3.0
# eval_mode: no
# Step: 1979 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 1980 | Predicted movie_id: 26078 | reward: 5.0
# eval_mode: no
# Step: 1981 | Predicted movie_id: 49263 | reward: 3.0
# eval_mode: no
# Step: 1982 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 1983 | Predicted movie_id: 134368 | reward: 3.5
# eval_mode: no
# Step: 1984 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 1985 | Predicted movie_id: 6939 | reward: 4.0
# eval_mode: no
# Step: 1986 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 1987 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 1988 | Predicted movie_id: 2518 | reward: 2.0
# eval_mode: no
# Step: 1989 | Predicted movie_id: 2471 | reward: 2.5
# eval_mode: no
# Step: 1990 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 1991 | Predicted movie_id: 46965 | reward: 2.5
# eval_mode: no
# Step: 1992 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 1993 | Predicted movie_id: 54796 | reward: 3.5
# eval_mode: no
# Step: 1994 | Predicted movie_id: 6145 | reward: 2.0
# eval_mode: no
# Step: 1995 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 1996 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 1997 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 1998 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 1999 | Predicted movie_id: 2696 | reward: 4.5
# eval_mode: no
# Step: 2000 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 2001 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 2002 | Predicted movie_id: 31522 | reward: 5.0
# eval_mode: no
# Step: 2003 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 2004 | Predicted movie_id: 53447 | reward: 4.0
# eval_mode: no
# Step: 2005 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 2006 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 2007 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 2008 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 2009 | Predicted movie_id: 3873 | reward: 3.0
# eval_mode: no
# Step: 2010 | Predicted movie_id: 4860 | reward: 2.0
# eval_mode: no
# Step: 2011 | Predicted movie_id: 3143 | reward: 3.0
# eval_mode: no
# Step: 2012 | Predicted movie_id: 6216 | reward: 4.0
# eval_mode: no
# Step: 2013 | Predicted movie_id: 2044 | reward: 3.0
# eval_mode: no
# Step: 2014 | Predicted movie_id: 263 | reward: 4.0
# eval_mode: no
# Step: 2015 | Predicted movie_id: 2055 | reward: 3.0
# eval_mode: no
# Step: 2016 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 2017 | Predicted movie_id: 27156 | reward: 4.5
# eval_mode: no
# Step: 2018 | Predicted movie_id: 8933 | reward: 4.0
# eval_mode: no
# Step: 2019 | Predicted movie_id: 26059 | reward: 4.5
# eval_mode: no
# Step: 2020 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 2021 | Predicted movie_id: 33132 | reward: 1.5
# eval_mode: no
# Step: 2022 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 2023 | Predicted movie_id: 1059 | reward: 3.5
# eval_mode: no
# Step: 2024 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 2025 | Predicted movie_id: 62644 | reward: 3.5
# eval_mode: no
# Step: 2026 | Predicted movie_id: 130976 | reward: 4.5
# eval_mode: no
# Step: 2027 | Predicted movie_id: 2518 | reward: 2.0
# eval_mode: no
# Step: 2028 | Predicted movie_id: 1177 | reward: 4.0
# eval_mode: no
# Step: 2029 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 2030 | Predicted movie_id: 79185 | reward: 3.5
# eval_mode: no
# Step: 2031 | Predicted movie_id: 6186 | reward: 3.0
# eval_mode: no
# Step: 2032 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 2033 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 2034 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 2035 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 2036 | Predicted movie_id: 2044 | reward: 3.0
# eval_mode: no
# Step: 2037 | Predicted movie_id: 1844 | reward: 4.0
# eval_mode: no
# Step: 2038 | Predicted movie_id: 2876 | reward: 2.0
# eval_mode: no
# Step: 2039 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 2040 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 2041 | Predicted movie_id: 89804 | reward: 3.0
# eval_mode: no
# Step: 2042 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 2043 | Predicted movie_id: 408 | reward: 3.0
# eval_mode: no
# Step: 2044 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 2045 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 2046 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 2047 | Predicted movie_id: 127298 | reward: 4.0
# eval_mode: no
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | 596      |
# | time/              |          |
# |    fps             | 96       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2048     |
# ---------------------------------

# %% [markdown]
# ##### Evaluate PPO model

# %%
max_ep_len = 100
episode_rewards = []
different_movie_counts = []
for i in range(10):
    test_env = create_custom_env(test_data, action_vocab=action_vocab, movie_embed_to_id=movie_embed_to_id, movies_ratings_and_tags=movies_ratings_and_tags, eval_mode='no')
    obs = test_env.reset()[0]
    rewards = 0
    movie_ids = []
    for t in range(max_ep_len):
        action, _ = model.predict(obs)
        # print(f"action: {action}, type: {type(action)}, shape: {action.shape}")
        obs, reward, done, _, action = test_env.step(action)
        # movie_ids.append(action)
        # print(f"reward: {reward}")
        rewards += reward
        if done:
            obs, _ = test_env.reset()
        # print(movie_ids)
    # unique_movie_count = len(set(movie_ids))
    # different_movie_counts.append(unique_movie_count)
    episode_rewards.append(rewards)
# Out:
# Step: 0 | Predicted movie_id: 3143 | reward: 3.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 2 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 3 | Predicted movie_id: 6706 | reward: 3.5
# eval_mode: no
# Step: 4 | Predicted movie_id: 3002 | reward: 4.0
# eval_mode: no
# Step: 5 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 6 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 7 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 8 | Predicted movie_id: 3268 | reward: 2.0
# eval_mode: no
# Step: 9 | Predicted movie_id: 3372 | reward: 4.0
# eval_mode: no
# Step: 10 | Predicted movie_id: 52694 | reward: 3.0
# eval_mode: no
# Step: 11 | Predicted movie_id: 64620 | reward: 4.0
# eval_mode: no
# Step: 12 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 13 | Predicted movie_id: 8340 | reward: 4.0
# eval_mode: no
# Step: 14 | Predicted movie_id: 65225 | reward: 4.5
# eval_mode: no
# Step: 15 | Predicted movie_id: 54796 | reward: 3.5
# eval_mode: no
# Step: 16 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 17 | Predicted movie_id: 114494 | reward: 1.5
# eval_mode: no
# Step: 18 | Predicted movie_id: 202 | reward: 3.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 4617 | reward: 3.5
# eval_mode: no
# Step: 20 | Predicted movie_id: 149612 | reward: 2.0
# eval_mode: no
# Step: 21 | Predicted movie_id: 183911 | reward: 1.5
# eval_mode: no
# Step: 22 | Predicted movie_id: 2188 | reward: 2.0
# eval_mode: no
# Step: 23 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 24 | Predicted movie_id: 4754 | reward: 4.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 26 | Predicted movie_id: 79185 | reward: 3.5
# eval_mode: no
# Step: 27 | Predicted movie_id: 80553 | reward: 3.5
# eval_mode: no
# Step: 28 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 29 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 30 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 31 | Predicted movie_id: 1132 | reward: 4.0
# eval_mode: no
# Step: 32 | Predicted movie_id: 2360 | reward: 4.5
# eval_mode: no
# Step: 33 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 34 | Predicted movie_id: 3173 | reward: 3.0
# eval_mode: no
# Step: 35 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 36 | Predicted movie_id: 366 | reward: 3.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 38 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 39 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 40 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 41 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 42 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 43 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 44 | Predicted movie_id: 2298 | reward: 4.0
# eval_mode: no
# Step: 45 | Predicted movie_id: 168712 | reward: 1.0
# eval_mode: no
# Step: 46 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 47 | Predicted movie_id: 1526 | reward: 1.0
# eval_mode: no
# Step: 48 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 49 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 50 | Predicted movie_id: 1177 | reward: 4.0
# eval_mode: no
# Step: 51 | Predicted movie_id: 3845 | reward: 4.0
# eval_mode: no
# Step: 52 | Predicted movie_id: 3021 | reward: 2.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 54 | Predicted movie_id: 98697 | reward: 2.5
# eval_mode: no
# Step: 55 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 56 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 57 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 58 | Predicted movie_id: 58156 | reward: 3.0
# eval_mode: no
# Step: 59 | Predicted movie_id: 6993 | reward: 4.0
# eval_mode: no
# Step: 60 | Predicted movie_id: 144262 | reward: 2.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 2794 | reward: 2.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 63 | Predicted movie_id: 27815 | reward: 4.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 65 | Predicted movie_id: 54796 | reward: 3.5
# eval_mode: no
# Step: 66 | Predicted movie_id: 7894 | reward: 3.5
# eval_mode: no
# Step: 67 | Predicted movie_id: 5963 | reward: 3.5
# eval_mode: no
# Step: 68 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 69 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 70 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 71 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 720 | reward: 4.0
# eval_mode: no
# Step: 73 | Predicted movie_id: 104644 | reward: 0.5
# eval_mode: no
# Step: 74 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 75 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 76 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 77 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 78 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 79 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 80 | Predicted movie_id: 122926 | reward: 4.0
# eval_mode: no
# Step: 81 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 82 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 83 | Predicted movie_id: 102058 | reward: 3.0
# eval_mode: no
# Step: 84 | Predicted movie_id: 6063 | reward: 3.5
# eval_mode: no
# Step: 85 | Predicted movie_id: 950 | reward: 4.0
# eval_mode: no
# Step: 86 | Predicted movie_id: 54734 | reward: 1.5
# eval_mode: no
# Step: 87 | Predicted movie_id: 64010 | reward: 3.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 6748 | reward: 3.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 175401 | reward: 4.0
# eval_mode: no
# Step: 90 | Predicted movie_id: 148166 | reward: 3.5
# eval_mode: no
# Step: 91 | Predicted movie_id: 3103 | reward: 3.0
# eval_mode: no
# Step: 92 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 93 | Predicted movie_id: 158388 | reward: 2.5
# eval_mode: no
# Step: 94 | Predicted movie_id: 114494 | reward: 1.5
# eval_mode: no
# Step: 95 | Predicted movie_id: 26073 | reward: 5.0
# eval_mode: no
# Step: 96 | Predicted movie_id: 52579 | reward: 3.0
# eval_mode: no
# Step: 97 | Predicted movie_id: 3893 | reward: 3.5
# eval_mode: no
# Step: 98 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 99 | Predicted movie_id: 45382 | reward: 3.0
# eval_mode: no
# Step: 0 | Predicted movie_id: 99638 | reward: 3.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 6598 | reward: 3.5
# eval_mode: no
# Step: 2 | Predicted movie_id: 1192 | reward: 4.5
# eval_mode: no
# Step: 3 | Predicted movie_id: 3508 | reward: 4.0
# eval_mode: no
# Step: 4 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 5 | Predicted movie_id: 2431 | reward: 3.5
# eval_mode: no
# Step: 6 | Predicted movie_id: 64620 | reward: 4.0
# eval_mode: no
# Step: 7 | Predicted movie_id: 122926 | reward: 4.0
# eval_mode: no
# Step: 8 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 9 | Predicted movie_id: 97230 | reward: 3.0
# eval_mode: no
# Step: 10 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 11 | Predicted movie_id: 3258 | reward: 3.0
# eval_mode: no
# Step: 12 | Predicted movie_id: 5108 | reward: 3.0
# eval_mode: no
# Step: 13 | Predicted movie_id: 26059 | reward: 4.5
# eval_mode: no
# Step: 14 | Predicted movie_id: 69654 | reward: 3.5
# eval_mode: no
# Step: 15 | Predicted movie_id: 190221 | reward: 1.0
# eval_mode: no
# Step: 16 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 17 | Predicted movie_id: 4349 | reward: 4.0
# eval_mode: no
# Step: 18 | Predicted movie_id: 97470 | reward: 1.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 95475 | reward: 4.0
# eval_mode: no
# Step: 20 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 21 | Predicted movie_id: 138210 | reward: 3.5
# eval_mode: no
# Step: 22 | Predicted movie_id: 3274 | reward: 3.5
# eval_mode: no
# Step: 23 | Predicted movie_id: 139157 | reward: 4.5
# eval_mode: no
# Step: 24 | Predicted movie_id: 58964 | reward: 4.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 26 | Predicted movie_id: 4888 | reward: 4.0
# eval_mode: no
# Step: 27 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 28 | Predicted movie_id: 4988 | reward: 2.0
# eval_mode: no
# Step: 29 | Predicted movie_id: 26681 | reward: 4.0
# eval_mode: no
# Step: 30 | Predicted movie_id: 103596 | reward: 2.0
# eval_mode: no
# Step: 31 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 32 | Predicted movie_id: 3088 | reward: 4.0
# eval_mode: no
# Step: 33 | Predicted movie_id: 55620 | reward: 3.0
# eval_mode: no
# Step: 34 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 35 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 36 | Predicted movie_id: 3508 | reward: 4.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 6063 | reward: 3.5
# eval_mode: no
# Step: 38 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 39 | Predicted movie_id: 55620 | reward: 3.0
# eval_mode: no
# Step: 40 | Predicted movie_id: 2794 | reward: 2.5
# eval_mode: no
# Step: 41 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 42 | Predicted movie_id: 76143 | reward: 4.5
# eval_mode: no
# Step: 43 | Predicted movie_id: 1251 | reward: 4.0
# eval_mode: no
# Step: 44 | Predicted movie_id: 1281 | reward: 4.0
# eval_mode: no
# Step: 45 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 46 | Predicted movie_id: 6201 | reward: 5.0
# eval_mode: no
# Step: 47 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 48 | Predicted movie_id: 2055 | reward: 3.0
# eval_mode: no
# Step: 49 | Predicted movie_id: 31522 | reward: 5.0
# eval_mode: no
# Step: 50 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 51 | Predicted movie_id: 199 | reward: 4.0
# eval_mode: no
# Step: 52 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 54 | Predicted movie_id: 59131 | reward: 3.5
# eval_mode: no
# Step: 55 | Predicted movie_id: 3088 | reward: 4.0
# eval_mode: no
# Step: 56 | Predicted movie_id: 5797 | reward: 2.0
# eval_mode: no
# Step: 57 | Predicted movie_id: 1461 | reward: 2.5
# eval_mode: no
# Step: 58 | Predicted movie_id: 45517 | reward: 3.5
# eval_mode: no
# Step: 59 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 60 | Predicted movie_id: 44943 | reward: 5.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 57243 | reward: 3.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 71327 | reward: 3.5
# eval_mode: no
# Step: 63 | Predicted movie_id: 168712 | reward: 1.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 2356 | reward: 2.5
# eval_mode: no
# Step: 65 | Predicted movie_id: 2772 | reward: 3.0
# eval_mode: no
# Step: 66 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 67 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 68 | Predicted movie_id: 57243 | reward: 3.5
# eval_mode: no
# Step: 69 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 70 | Predicted movie_id: 6985 | reward: 4.0
# eval_mode: no
# Step: 71 | Predicted movie_id: 7745 | reward: 4.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 2044 | reward: 2.5
# eval_mode: no
# Step: 73 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 74 | Predicted movie_id: 55620 | reward: 3.0
# eval_mode: no
# Step: 75 | Predicted movie_id: 2544 | reward: 3.0
# eval_mode: no
# Step: 76 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 77 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 78 | Predicted movie_id: 41712 | reward: 4.0
# eval_mode: no
# Step: 79 | Predicted movie_id: 32294 | reward: 3.5
# eval_mode: no
# Step: 80 | Predicted movie_id: 65225 | reward: 4.5
# eval_mode: no
# Step: 81 | Predicted movie_id: 102058 | reward: 3.0
# eval_mode: no
# Step: 82 | Predicted movie_id: 71252 | reward: 2.5
# eval_mode: no
# Step: 83 | Predicted movie_id: 1856 | reward: 4.0
# eval_mode: no
# Step: 84 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 85 | Predicted movie_id: 3479 | reward: 3.5
# eval_mode: no
# Step: 86 | Predicted movie_id: 1224 | reward: 4.0
# eval_mode: no
# Step: 87 | Predicted movie_id: 3893 | reward: 3.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 4349 | reward: 4.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 115151 | reward: 2.0
# eval_mode: no
# Step: 90 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 91 | Predicted movie_id: 39715 | reward: 2.5
# eval_mode: no
# Step: 92 | Predicted movie_id: 79185 | reward: 4.0
# eval_mode: no
# Step: 93 | Predicted movie_id: 3143 | reward: 3.0
# eval_mode: no
# Step: 94 | Predicted movie_id: 91860 | reward: 4.0
# eval_mode: no
# Step: 95 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 96 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 97 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 98 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 99 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 0 | Predicted movie_id: 5607 | reward: 5.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 2 | Predicted movie_id: 1863 | reward: 2.5
# eval_mode: no
# Step: 3 | Predicted movie_id: 5218 | reward: 3.5
# eval_mode: no
# Step: 4 | Predicted movie_id: 3893 | reward: 3.5
# eval_mode: no
# Step: 5 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 6 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 7 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 8 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 9 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 10 | Predicted movie_id: 56152 | reward: 3.5
# eval_mode: no
# Step: 11 | Predicted movie_id: 6566 | reward: 2.0
# eval_mode: no
# Step: 12 | Predicted movie_id: 1860 | reward: 2.5
# eval_mode: no
# Step: 13 | Predicted movie_id: 58964 | reward: 4.0
# eval_mode: no
# Step: 14 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 15 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 16 | Predicted movie_id: 172497 | reward: 4.0
# eval_mode: no
# Step: 17 | Predicted movie_id: 4663 | reward: 3.0
# eval_mode: no
# Step: 18 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 19 | Predicted movie_id: 55814 | reward: 4.0
# eval_mode: no
# Step: 20 | Predicted movie_id: 3143 | reward: 3.0
# eval_mode: no
# Step: 21 | Predicted movie_id: 74647 | reward: 1.0
# eval_mode: no
# Step: 22 | Predicted movie_id: 5699 | reward: 4.0
# eval_mode: no
# Step: 23 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 24 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 26 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 27 | Predicted movie_id: 26761 | reward: 3.0
# eval_mode: no
# Step: 28 | Predicted movie_id: 1132 | reward: 4.0
# eval_mode: no
# Step: 29 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 30 | Predicted movie_id: 82242 | reward: 4.0
# eval_mode: no
# Step: 31 | Predicted movie_id: 4242 | reward: 2.0
# eval_mode: no
# Step: 32 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 33 | Predicted movie_id: 190221 | reward: 1.0
# eval_mode: no
# Step: 34 | Predicted movie_id: 59014 | reward: 2.0
# eval_mode: no
# Step: 35 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 36 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 6985 | reward: 4.0
# eval_mode: no
# Step: 38 | Predicted movie_id: 85354 | reward: 3.5
# eval_mode: no
# Step: 39 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 40 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 41 | Predicted movie_id: 2742 | reward: 1.0
# eval_mode: no
# Step: 42 | Predicted movie_id: 823 | reward: 3.5
# eval_mode: no
# Step: 43 | Predicted movie_id: 1735 | reward: 3.5
# eval_mode: no
# Step: 44 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 45 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 46 | Predicted movie_id: 26761 | reward: 3.0
# eval_mode: no
# Step: 47 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 48 | Predicted movie_id: 130073 | reward: 4.0
# eval_mode: no
# Step: 49 | Predicted movie_id: 232 | reward: 1.5
# eval_mode: no
# Step: 50 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 51 | Predicted movie_id: 461 | reward: 3.0
# eval_mode: no
# Step: 52 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 54 | Predicted movie_id: 81537 | reward: 3.0
# eval_mode: no
# Step: 55 | Predicted movie_id: 165483 | reward: 4.0
# eval_mode: no
# Step: 56 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 57 | Predicted movie_id: 134184 | reward: 4.5
# eval_mode: no
# Step: 58 | Predicted movie_id: 7894 | reward: 3.5
# eval_mode: no
# Step: 59 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 60 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 61 | Predicted movie_id: 104879 | reward: 4.0
# eval_mode: no
# Step: 62 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 63 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 74647 | reward: 1.0
# eval_mode: no
# Step: 65 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 66 | Predicted movie_id: 98230 | reward: 3.5
# eval_mode: no
# Step: 67 | Predicted movie_id: 142598 | reward: 4.0
# eval_mode: no
# Step: 68 | Predicted movie_id: 2414 | reward: 3.5
# eval_mode: no
# Step: 69 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 70 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 71 | Predicted movie_id: 134109 | reward: 5.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 2544 | reward: 3.0
# eval_mode: no
# Step: 73 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 74 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 75 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 76 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 77 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 78 | Predicted movie_id: 65651 | reward: 2.0
# eval_mode: no
# Step: 79 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 80 | Predicted movie_id: 76143 | reward: 4.5
# eval_mode: no
# Step: 81 | Predicted movie_id: 2414 | reward: 3.5
# eval_mode: no
# Step: 82 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 83 | Predicted movie_id: 2423 | reward: 3.5
# eval_mode: no
# Step: 84 | Predicted movie_id: 7063 | reward: 4.0
# eval_mode: no
# Step: 85 | Predicted movie_id: 122892 | reward: 3.5
# eval_mode: no
# Step: 86 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 87 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 86286 | reward: 2.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 80478 | reward: 4.0
# eval_mode: no
# Step: 90 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 91 | Predicted movie_id: 101612 | reward: 3.0
# eval_mode: no
# Step: 92 | Predicted movie_id: 134849 | reward: 4.0
# eval_mode: no
# Step: 93 | Predicted movie_id: 104129 | reward: 3.0
# eval_mode: no
# Step: 94 | Predicted movie_id: 263 | reward: 4.0
# eval_mode: no
# Step: 95 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 96 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 97 | Predicted movie_id: 65225 | reward: 4.5
# eval_mode: no
# Step: 98 | Predicted movie_id: 3814 | reward: 4.0
# eval_mode: no
# Step: 99 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 0 | Predicted movie_id: 66198 | reward: 3.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 2 | Predicted movie_id: 143896 | reward: 4.5
# eval_mode: no
# Step: 3 | Predicted movie_id: 4973 | reward: 4.0
# eval_mode: no
# Step: 4 | Predicted movie_id: 109313 | reward: 4.0
# eval_mode: no
# Step: 5 | Predicted movie_id: 6593 | reward: 3.0
# eval_mode: no
# Step: 6 | Predicted movie_id: 131610 | reward: 5.0
# eval_mode: no
# Step: 7 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 8 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 9 | Predicted movie_id: 780 | reward: 5.0
# eval_mode: no
# Step: 10 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 11 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 12 | Predicted movie_id: 6063 | reward: 3.5
# eval_mode: no
# Step: 13 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 14 | Predicted movie_id: 55814 | reward: 4.0
# eval_mode: no
# Step: 15 | Predicted movie_id: 97665 | reward: 2.5
# eval_mode: no
# Step: 16 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 17 | Predicted movie_id: 81562 | reward: 4.0
# eval_mode: no
# Step: 18 | Predicted movie_id: 5971 | reward: 4.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 71640 | reward: 3.5
# eval_mode: no
# Step: 20 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 21 | Predicted movie_id: 7028 | reward: 3.5
# eval_mode: no
# Step: 22 | Predicted movie_id: 101962 | reward: 4.0
# eval_mode: no
# Step: 23 | Predicted movie_id: 5137 | reward: 4.0
# eval_mode: no
# Step: 24 | Predicted movie_id: 4896 | reward: 4.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 1177 | reward: 4.0
# eval_mode: no
# Step: 26 | Predicted movie_id: 142456 | reward: 4.0
# eval_mode: no
# Step: 27 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 28 | Predicted movie_id: 129354 | reward: 3.0
# eval_mode: no
# Step: 29 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 30 | Predicted movie_id: 105211 | reward: 3.0
# eval_mode: no
# Step: 31 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 32 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 33 | Predicted movie_id: 8239 | reward: 4.0
# eval_mode: no
# Step: 34 | Predicted movie_id: 158388 | reward: 2.5
# eval_mode: no
# Step: 35 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 36 | Predicted movie_id: 55492 | reward: 4.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 65037 | reward: 3.5
# eval_mode: no
# Step: 38 | Predicted movie_id: 144262 | reward: 2.0
# eval_mode: no
# Step: 39 | Predicted movie_id: 175401 | reward: 4.0
# eval_mode: no
# Step: 40 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 41 | Predicted movie_id: 1261 | reward: 4.0
# eval_mode: no
# Step: 42 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 43 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 44 | Predicted movie_id: 3453 | reward: 3.0
# eval_mode: no
# Step: 45 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 46 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 47 | Predicted movie_id: 4202 | reward: 3.0
# eval_mode: no
# Step: 48 | Predicted movie_id: 2044 | reward: 2.5
# eval_mode: no
# Step: 49 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 50 | Predicted movie_id: 167036 | reward: 4.0
# eval_mode: no
# Step: 51 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 52 | Predicted movie_id: 5607 | reward: 5.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 54 | Predicted movie_id: 1111 | reward: 4.0
# eval_mode: no
# Step: 55 | Predicted movie_id: 5275 | reward: 1.5
# eval_mode: no
# Step: 56 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 57 | Predicted movie_id: 6893 | reward: 4.0
# eval_mode: no
# Step: 58 | Predicted movie_id: 4502 | reward: 1.5
# eval_mode: no
# Step: 59 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 60 | Predicted movie_id: 6271 | reward: 2.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 284 | reward: 4.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 6214 | reward: 4.0
# eval_mode: no
# Step: 63 | Predicted movie_id: 47423 | reward: 4.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 70545 | reward: 2.0
# eval_mode: no
# Step: 65 | Predicted movie_id: 56152 | reward: 3.5
# eval_mode: no
# Step: 66 | Predicted movie_id: 3855 | reward: 5.0
# eval_mode: no
# Step: 67 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 68 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 69 | Predicted movie_id: 8575 | reward: 3.0
# eval_mode: no
# Step: 70 | Predicted movie_id: 26743 | reward: 2.5
# eval_mode: no
# Step: 71 | Predicted movie_id: 8239 | reward: 4.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 73 | Predicted movie_id: 1116 | reward: 4.0
# eval_mode: no
# Step: 74 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 75 | Predicted movie_id: 2544 | reward: 3.0
# eval_mode: no
# Step: 76 | Predicted movie_id: 4010 | reward: 3.0
# eval_mode: no
# Step: 77 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 78 | Predicted movie_id: 6973 | reward: 2.5
# eval_mode: no
# Step: 79 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 80 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 81 | Predicted movie_id: 56060 | reward: 4.5
# eval_mode: no
# Step: 82 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 83 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 84 | Predicted movie_id: 64620 | reward: 4.0
# eval_mode: no
# Step: 85 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 86 | Predicted movie_id: 408 | reward: 3.0
# eval_mode: no
# Step: 87 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 58156 | reward: 3.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 57243 | reward: 3.5
# eval_mode: no
# Step: 90 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 91 | Predicted movie_id: 1347 | reward: 3.0
# eval_mode: no
# Step: 92 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 93 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 94 | Predicted movie_id: 4380 | reward: 4.0
# eval_mode: no
# Step: 95 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 96 | Predicted movie_id: 71867 | reward: 3.0
# eval_mode: no
# Step: 97 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 98 | Predicted movie_id: 8933 | reward: 4.0
# eval_mode: no
# Step: 99 | Predicted movie_id: 43936 | reward: 3.0
# eval_mode: no
# Step: 0 | Predicted movie_id: 81786 | reward: 4.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 2 | Predicted movie_id: 202 | reward: 3.0
# eval_mode: no
# Step: 3 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 4 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 5 | Predicted movie_id: 79185 | reward: 3.5
# eval_mode: no
# Step: 6 | Predicted movie_id: 80166 | reward: 2.5
# eval_mode: no
# Step: 7 | Predicted movie_id: 8804 | reward: 5.0
# eval_mode: no
# Step: 8 | Predicted movie_id: 6985 | reward: 4.0
# eval_mode: no
# Step: 9 | Predicted movie_id: 6973 | reward: 2.5
# eval_mode: no
# Step: 10 | Predicted movie_id: 4380 | reward: 4.0
# eval_mode: no
# Step: 11 | Predicted movie_id: 47950 | reward: 3.0
# eval_mode: no
# Step: 12 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 13 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 14 | Predicted movie_id: 97188 | reward: 4.0
# eval_mode: no
# Step: 15 | Predicted movie_id: 85354 | reward: 3.5
# eval_mode: no
# Step: 16 | Predicted movie_id: 3764 | reward: 2.5
# eval_mode: no
# Step: 17 | Predicted movie_id: 2732 | reward: 4.5
# eval_mode: no
# Step: 18 | Predicted movie_id: 3816 | reward: 4.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 931 | reward: 4.0
# eval_mode: no
# Step: 20 | Predicted movie_id: 111913 | reward: 4.5
# eval_mode: no
# Step: 21 | Predicted movie_id: 3274 | reward: 3.5
# eval_mode: no
# Step: 22 | Predicted movie_id: 80166 | reward: 2.5
# eval_mode: no
# Step: 23 | Predicted movie_id: 132424 | reward: 2.0
# eval_mode: no
# Step: 24 | Predicted movie_id: 8755 | reward: 3.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 82093 | reward: 1.5
# eval_mode: no
# Step: 26 | Predicted movie_id: 140267 | reward: 4.0
# eval_mode: no
# Step: 27 | Predicted movie_id: 3845 | reward: 4.0
# eval_mode: no
# Step: 28 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 29 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 30 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 31 | Predicted movie_id: 3516 | reward: 3.5
# eval_mode: no
# Step: 32 | Predicted movie_id: 27820 | reward: 4.0
# eval_mode: no
# Step: 33 | Predicted movie_id: 3372 | reward: 4.0
# eval_mode: no
# Step: 34 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 35 | Predicted movie_id: 34148 | reward: 3.0
# eval_mode: no
# Step: 36 | Predicted movie_id: 3274 | reward: 3.5
# eval_mode: no
# Step: 37 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 38 | Predicted movie_id: 101072 | reward: 2.5
# eval_mode: no
# Step: 39 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 40 | Predicted movie_id: 6973 | reward: 2.5
# eval_mode: no
# Step: 41 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 42 | Predicted movie_id: 719 | reward: 3.0
# eval_mode: no
# Step: 43 | Predicted movie_id: 82242 | reward: 4.0
# eval_mode: no
# Step: 44 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 45 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 46 | Predicted movie_id: 172497 | reward: 4.0
# eval_mode: no
# Step: 47 | Predicted movie_id: 57243 | reward: 3.5
# eval_mode: no
# Step: 48 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 49 | Predicted movie_id: 68486 | reward: 4.0
# eval_mode: no
# Step: 50 | Predicted movie_id: 2076 | reward: 4.0
# eval_mode: no
# Step: 51 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 52 | Predicted movie_id: 6985 | reward: 4.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 54 | Predicted movie_id: 148166 | reward: 3.5
# eval_mode: no
# Step: 55 | Predicted movie_id: 1694 | reward: 3.0
# eval_mode: no
# Step: 56 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 57 | Predicted movie_id: 477 | reward: 3.0
# eval_mode: no
# Step: 58 | Predicted movie_id: 3515 | reward: 3.5
# eval_mode: no
# Step: 59 | Predicted movie_id: 3459 | reward: 4.0
# eval_mode: no
# Step: 60 | Predicted movie_id: 2813 | reward: 1.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 1323 | reward: 1.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 63 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 64 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 65 | Predicted movie_id: 8677 | reward: 1.0
# eval_mode: no
# Step: 66 | Predicted movie_id: 76143 | reward: 4.5
# eval_mode: no
# Step: 67 | Predicted movie_id: 164200 | reward: 4.0
# eval_mode: no
# Step: 68 | Predicted movie_id: 27815 | reward: 4.0
# eval_mode: no
# Step: 69 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 70 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 71 | Predicted movie_id: 6869 | reward: 4.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 73 | Predicted movie_id: 102058 | reward: 3.0
# eval_mode: no
# Step: 74 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 75 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 76 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 77 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 78 | Predicted movie_id: 26225 | reward: 4.5
# eval_mode: no
# Step: 79 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 80 | Predicted movie_id: 3845 | reward: 4.0
# eval_mode: no
# Step: 81 | Predicted movie_id: 168712 | reward: 1.0
# eval_mode: no
# Step: 82 | Predicted movie_id: 27839 | reward: 2.5
# eval_mode: no
# Step: 83 | Predicted movie_id: 1907 | reward: 3.5
# eval_mode: no
# Step: 84 | Predicted movie_id: 159441 | reward: 3.5
# eval_mode: no
# Step: 85 | Predicted movie_id: 6809 | reward: 3.0
# eval_mode: no
# Step: 86 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 87 | Predicted movie_id: 71252 | reward: 2.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 2794 | reward: 2.5
# eval_mode: no
# Step: 89 | Predicted movie_id: 5465 | reward: 3.0
# eval_mode: no
# Step: 90 | Predicted movie_id: 27156 | reward: 4.5
# eval_mode: no
# Step: 91 | Predicted movie_id: 490 | reward: 2.0
# eval_mode: no
# Step: 92 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 93 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 94 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 95 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 96 | Predicted movie_id: 2794 | reward: 2.5
# eval_mode: no
# Step: 97 | Predicted movie_id: 140267 | reward: 4.0
# eval_mode: no
# Step: 98 | Predicted movie_id: 48738 | reward: 4.0
# eval_mode: no
# Step: 99 | Predicted movie_id: 142456 | reward: 4.0
# eval_mode: no
# Step: 0 | Predicted movie_id: 6772 | reward: 3.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 8575 | reward: 3.0
# eval_mode: no
# Step: 2 | Predicted movie_id: 8228 | reward: 3.5
# eval_mode: no
# Step: 3 | Predicted movie_id: 62644 | reward: 3.5
# eval_mode: no
# Step: 4 | Predicted movie_id: 3143 | reward: 3.0
# eval_mode: no
# Step: 5 | Predicted movie_id: 2575 | reward: 4.0
# eval_mode: no
# Step: 6 | Predicted movie_id: 7487 | reward: 4.0
# eval_mode: no
# Step: 7 | Predicted movie_id: 2044 | reward: 2.5
# eval_mode: no
# Step: 8 | Predicted movie_id: 102058 | reward: 3.0
# eval_mode: no
# Step: 9 | Predicted movie_id: 725 | reward: 2.5
# eval_mode: no
# Step: 10 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 11 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 12 | Predicted movie_id: 81786 | reward: 4.0
# eval_mode: no
# Step: 13 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 14 | Predicted movie_id: 54934 | reward: 0.5
# eval_mode: no
# Step: 15 | Predicted movie_id: 6214 | reward: 4.0
# eval_mode: no
# Step: 16 | Predicted movie_id: 58156 | reward: 3.0
# eval_mode: no
# Step: 17 | Predicted movie_id: 168252 | reward: 4.5
# eval_mode: no
# Step: 18 | Predicted movie_id: 77798 | reward: 1.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 1544 | reward: 3.0
# eval_mode: no
# Step: 20 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 21 | Predicted movie_id: 131013 | reward: 3.0
# eval_mode: no
# Step: 22 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 23 | Predicted movie_id: 2048 | reward: 3.5
# eval_mode: no
# Step: 24 | Predicted movie_id: 5618 | reward: 4.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 477 | reward: 3.5
# eval_mode: no
# Step: 26 | Predicted movie_id: 122912 | reward: 4.0
# eval_mode: no
# Step: 27 | Predicted movie_id: 178615 | reward: 3.5
# eval_mode: no
# Step: 28 | Predicted movie_id: 78574 | reward: 3.5
# eval_mode: no
# Step: 29 | Predicted movie_id: 117109 | reward: 3.0
# eval_mode: no
# Step: 30 | Predicted movie_id: 54276 | reward: 3.0
# eval_mode: no
# Step: 31 | Predicted movie_id: 2081 | reward: 3.5
# eval_mode: no
# Step: 32 | Predicted movie_id: 4380 | reward: 4.0
# eval_mode: no
# Step: 33 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 34 | Predicted movie_id: 7894 | reward: 3.5
# eval_mode: no
# Step: 35 | Predicted movie_id: 84615 | reward: 2.0
# eval_mode: no
# Step: 36 | Predicted movie_id: 5884 | reward: 1.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 38 | Predicted movie_id: 32589 | reward: 2.0
# eval_mode: no
# Step: 39 | Predicted movie_id: 114494 | reward: 1.5
# eval_mode: no
# Step: 40 | Predicted movie_id: 3989 | reward: 4.0
# eval_mode: no
# Step: 41 | Predicted movie_id: 8575 | reward: 3.0
# eval_mode: no
# Step: 42 | Predicted movie_id: 178615 | reward: 3.5
# eval_mode: no
# Step: 43 | Predicted movie_id: 160684 | reward: 3.5
# eval_mode: no
# Step: 44 | Predicted movie_id: 3385 | reward: 3.0
# eval_mode: no
# Step: 45 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 46 | Predicted movie_id: 31696 | reward: 3.5
# eval_mode: no
# Step: 47 | Predicted movie_id: 4399 | reward: 4.0
# eval_mode: no
# Step: 48 | Predicted movie_id: 115149 | reward: 4.0
# eval_mode: no
# Step: 49 | Predicted movie_id: 33499 | reward: 2.5
# eval_mode: no
# Step: 50 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 51 | Predicted movie_id: 31522 | reward: 5.0
# eval_mode: no
# Step: 52 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 53 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 54 | Predicted movie_id: 4424 | reward: 3.5
# eval_mode: no
# Step: 55 | Predicted movie_id: 5736 | reward: 1.5
# eval_mode: no
# Step: 56 | Predicted movie_id: 127298 | reward: 4.0
# eval_mode: no
# Step: 57 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 58 | Predicted movie_id: 1251 | reward: 4.0
# eval_mode: no
# Step: 59 | Predicted movie_id: 6158 | reward: 3.0
# eval_mode: no
# Step: 60 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 65225 | reward: 4.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 2081 | reward: 3.5
# eval_mode: no
# Step: 63 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 101612 | reward: 3.0
# eval_mode: no
# Step: 65 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 66 | Predicted movie_id: 104339 | reward: 4.0
# eval_mode: no
# Step: 67 | Predicted movie_id: 1998 | reward: 1.5
# eval_mode: no
# Step: 68 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 69 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 70 | Predicted movie_id: 64620 | reward: 4.0
# eval_mode: no
# Step: 71 | Predicted movie_id: 31225 | reward: 3.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 1330 | reward: 1.5
# eval_mode: no
# Step: 73 | Predicted movie_id: 1251 | reward: 4.0
# eval_mode: no
# Step: 74 | Predicted movie_id: 1969 | reward: 2.5
# eval_mode: no
# Step: 75 | Predicted movie_id: 2187 | reward: 3.5
# eval_mode: no
# Step: 76 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 77 | Predicted movie_id: 96004 | reward: 3.0
# eval_mode: no
# Step: 78 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 79 | Predicted movie_id: 7742 | reward: 0.5
# eval_mode: no
# Step: 80 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 81 | Predicted movie_id: 5443 | reward: 1.5
# eval_mode: no
# Step: 82 | Predicted movie_id: 51082 | reward: 2.0
# eval_mode: no
# Step: 83 | Predicted movie_id: 31522 | reward: 5.0
# eval_mode: no
# Step: 84 | Predicted movie_id: 7492 | reward: 4.0
# eval_mode: no
# Step: 85 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 86 | Predicted movie_id: 8575 | reward: 3.0
# eval_mode: no
# Step: 87 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 88 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 97285 | reward: 3.5
# eval_mode: no
# Step: 90 | Predicted movie_id: 626 | reward: 5.0
# eval_mode: no
# Step: 91 | Predicted movie_id: 33683 | reward: 4.0
# eval_mode: no
# Step: 92 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 93 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 94 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 95 | Predicted movie_id: 52579 | reward: 3.0
# eval_mode: no
# Step: 96 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 97 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 98 | Predicted movie_id: 3173 | reward: 3.0
# eval_mode: no
# Step: 99 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 0 | Predicted movie_id: 86347 | reward: 3.5
# eval_mode: no
# Step: 1 | Predicted movie_id: 3254 | reward: 3.5
# eval_mode: no
# Step: 2 | Predicted movie_id: 1431 | reward: 2.5
# eval_mode: no
# Step: 3 | Predicted movie_id: 1975 | reward: 2.5
# eval_mode: no
# Step: 4 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 5 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 6 | Predicted movie_id: 79185 | reward: 3.5
# eval_mode: no
# Step: 7 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 8 | Predicted movie_id: 2544 | reward: 3.0
# eval_mode: no
# Step: 9 | Predicted movie_id: 100714 | reward: 3.5
# eval_mode: no
# Step: 10 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 11 | Predicted movie_id: 1747 | reward: 3.5
# eval_mode: no
# Step: 12 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 13 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 14 | Predicted movie_id: 120637 | reward: 2.5
# eval_mode: no
# Step: 15 | Predicted movie_id: 100507 | reward: 3.5
# eval_mode: no
# Step: 16 | Predicted movie_id: 4623 | reward: 3.5
# eval_mode: no
# Step: 17 | Predicted movie_id: 7349 | reward: 3.0
# eval_mode: no
# Step: 18 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 7624 | reward: 3.0
# eval_mode: no
# Step: 20 | Predicted movie_id: 127194 | reward: 2.0
# eval_mode: no
# Step: 21 | Predicted movie_id: 107565 | reward: 3.0
# eval_mode: no
# Step: 22 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 23 | Predicted movie_id: 1238 | reward: 4.0
# eval_mode: no
# Step: 24 | Predicted movie_id: 6722 | reward: 2.5
# eval_mode: no
# Step: 25 | Predicted movie_id: 8984 | reward: 3.5
# eval_mode: no
# Step: 26 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 27 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 28 | Predicted movie_id: 4404 | reward: 4.0
# eval_mode: no
# Step: 29 | Predicted movie_id: 78637 | reward: 3.5
# eval_mode: no
# Step: 30 | Predicted movie_id: 2082 | reward: 2.5
# eval_mode: no
# Step: 31 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 32 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 33 | Predicted movie_id: 140 | reward: 3.5
# eval_mode: no
# Step: 34 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 35 | Predicted movie_id: 3920 | reward: 4.0
# eval_mode: no
# Step: 36 | Predicted movie_id: 5971 | reward: 4.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 38 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 39 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 40 | Predicted movie_id: 161 | reward: 3.5
# eval_mode: no
# Step: 41 | Predicted movie_id: 54768 | reward: 0.5
# eval_mode: no
# Step: 42 | Predicted movie_id: 1358 | reward: 4.0
# eval_mode: no
# Step: 43 | Predicted movie_id: 74677 | reward: 4.0
# eval_mode: no
# Step: 44 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 45 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 46 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 47 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 48 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 49 | Predicted movie_id: 1863 | reward: 2.5
# eval_mode: no
# Step: 50 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 51 | Predicted movie_id: 42738 | reward: 3.0
# eval_mode: no
# Step: 52 | Predicted movie_id: 8128 | reward: 4.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 54 | Predicted movie_id: 98697 | reward: 2.5
# eval_mode: no
# Step: 55 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 56 | Predicted movie_id: 59429 | reward: 3.0
# eval_mode: no
# Step: 57 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 58 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 59 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 60 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 61 | Predicted movie_id: 2633 | reward: 3.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 63 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 8622 | reward: 3.5
# eval_mode: no
# Step: 65 | Predicted movie_id: 41724 | reward: 4.5
# eval_mode: no
# Step: 66 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 67 | Predicted movie_id: 3308 | reward: 3.0
# eval_mode: no
# Step: 68 | Predicted movie_id: 71640 | reward: 3.5
# eval_mode: no
# Step: 69 | Predicted movie_id: 1955 | reward: 4.0
# eval_mode: no
# Step: 70 | Predicted movie_id: 2544 | reward: 3.0
# eval_mode: no
# Step: 71 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 134849 | reward: 4.0
# eval_mode: no
# Step: 73 | Predicted movie_id: 2044 | reward: 2.5
# eval_mode: no
# Step: 74 | Predicted movie_id: 8972 | reward: 3.5
# eval_mode: no
# Step: 75 | Predicted movie_id: 55553 | reward: 2.5
# eval_mode: no
# Step: 76 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 77 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 78 | Predicted movie_id: 212 | reward: 3.0
# eval_mode: no
# Step: 79 | Predicted movie_id: 26761 | reward: 3.0
# eval_mode: no
# Step: 80 | Predicted movie_id: 167036 | reward: 4.0
# eval_mode: no
# Step: 81 | Predicted movie_id: 54617 | reward: 3.5
# eval_mode: no
# Step: 82 | Predicted movie_id: 171891 | reward: 3.5
# eval_mode: no
# Step: 83 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 84 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 85 | Predicted movie_id: 3893 | reward: 3.5
# eval_mode: no
# Step: 86 | Predicted movie_id: 6794 | reward: 1.5
# eval_mode: no
# Step: 87 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 26761 | reward: 3.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 3633 | reward: 3.5
# eval_mode: no
# Step: 90 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 91 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 92 | Predicted movie_id: 7894 | reward: 3.5
# eval_mode: no
# Step: 93 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 94 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 95 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 96 | Predicted movie_id: 1358 | reward: 4.0
# eval_mode: no
# Step: 97 | Predicted movie_id: 271 | reward: 3.5
# eval_mode: no
# Step: 98 | Predicted movie_id: 101072 | reward: 2.5
# eval_mode: no
# Step: 99 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 0 | Predicted movie_id: 109295 | reward: 2.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 57522 | reward: 3.5
# eval_mode: no
# Step: 2 | Predicted movie_id: 89864 | reward: 3.5
# eval_mode: no
# Step: 3 | Predicted movie_id: 27815 | reward: 4.0
# eval_mode: no
# Step: 4 | Predicted movie_id: 2044 | reward: 2.5
# eval_mode: no
# Step: 5 | Predicted movie_id: 59429 | reward: 3.0
# eval_mode: no
# Step: 6 | Predicted movie_id: 57243 | reward: 3.5
# eval_mode: no
# Step: 7 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 8 | Predicted movie_id: 8484 | reward: 4.5
# eval_mode: no
# Step: 9 | Predicted movie_id: 129354 | reward: 3.0
# eval_mode: no
# Step: 10 | Predicted movie_id: 263 | reward: 4.0
# eval_mode: no
# Step: 11 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 12 | Predicted movie_id: 170697 | reward: 4.0
# eval_mode: no
# Step: 13 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 14 | Predicted movie_id: 88094 | reward: 3.0
# eval_mode: no
# Step: 15 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 16 | Predicted movie_id: 6962 | reward: 3.5
# eval_mode: no
# Step: 17 | Predicted movie_id: 45517 | reward: 3.5
# eval_mode: no
# Step: 18 | Predicted movie_id: 34129 | reward: 3.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 26225 | reward: 4.5
# eval_mode: no
# Step: 20 | Predicted movie_id: 67888 | reward: 4.5
# eval_mode: no
# Step: 21 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 22 | Predicted movie_id: 1021 | reward: 2.5
# eval_mode: no
# Step: 23 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 24 | Predicted movie_id: 26694 | reward: 3.5
# eval_mode: no
# Step: 25 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 26 | Predicted movie_id: 31150 | reward: 2.0
# eval_mode: no
# Step: 27 | Predicted movie_id: 84615 | reward: 2.0
# eval_mode: no
# Step: 28 | Predicted movie_id: 1227 | reward: 4.0
# eval_mode: no
# Step: 29 | Predicted movie_id: 791 | reward: 4.0
# eval_mode: no
# Step: 30 | Predicted movie_id: 44943 | reward: 5.0
# eval_mode: no
# Step: 31 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 32 | Predicted movie_id: 115877 | reward: 3.5
# eval_mode: no
# Step: 33 | Predicted movie_id: 81786 | reward: 4.0
# eval_mode: no
# Step: 34 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 35 | Predicted movie_id: 58376 | reward: 4.0
# eval_mode: no
# Step: 36 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 37 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 38 | Predicted movie_id: 4008 | reward: 3.5
# eval_mode: no
# Step: 39 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 40 | Predicted movie_id: 67788 | reward: 3.5
# eval_mode: no
# Step: 41 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 42 | Predicted movie_id: 131023 | reward: 4.5
# eval_mode: no
# Step: 43 | Predicted movie_id: 1009 | reward: 3.0
# ...
# eval_mode: no
# Step: 53 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 54 | Predicted movie_id: 101072 | reward: 2.5
# eval_mode: no
# Step: 55 | Predicted movie_id: 184721 | reward: 4.0
# eval_mode: no
# Step: 56 | Predicted movie_id: 7349 | reward: 3.0
# eval_mode: no
# Step: 57 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 58 | Predicted movie_id: 65261 | reward: 4.0
# eval_mode: no
# Step: 59 | Predicted movie_id: 7925 | reward: 4.0
# eval_mode: no
# Step: 60 | Predicted movie_id: 5353 | reward: 3.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 103219 | reward: 3.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 50189 | reward: 1.0
# eval_mode: no
# Step: 63 | Predicted movie_id: 44943 | reward: 5.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 51933 | reward: 2.5
# eval_mode: no
# Step: 65 | Predicted movie_id: 85774 | reward: 4.0
# eval_mode: no
# Step: 66 | Predicted movie_id: 5458 | reward: 2.5
# eval_mode: no
# Step: 67 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 68 | Predicted movie_id: 76143 | reward: 4.5
# eval_mode: no
# Step: 69 | Predicted movie_id: 141718 | reward: 5.0
# eval_mode: no
# Step: 70 | Predicted movie_id: 556 | reward: 3.5
# eval_mode: no
# Step: 71 | Predicted movie_id: 64993 | reward: 3.5
# eval_mode: no
# Step: 72 | Predicted movie_id: 4970 | reward: 4.0
# eval_mode: no
# Step: 73 | Predicted movie_id: 142196 | reward: 4.5
# eval_mode: no
# Step: 74 | Predicted movie_id: 3015 | reward: 3.5
# eval_mode: no
# Step: 75 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 76 | Predicted movie_id: 26492 | reward: 3.0
# eval_mode: no
# Step: 77 | Predicted movie_id: 136471 | reward: 3.5
# eval_mode: no
# Step: 78 | Predicted movie_id: 140 | reward: 3.5
# eval_mode: no
# Step: 79 | Predicted movie_id: 64497 | reward: 3.0
# eval_mode: no
# Step: 80 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 81 | Predicted movie_id: 72733 | reward: 4.0
# eval_mode: no
# Step: 82 | Predicted movie_id: 2044 | reward: 2.5
# eval_mode: no
# Step: 83 | Predicted movie_id: 4237 | reward: 4.0
# eval_mode: no
# Step: 84 | Predicted movie_id: 25782 | reward: 0.5
# eval_mode: no
# Step: 85 | Predicted movie_id: 54796 | reward: 3.5
# eval_mode: no
# Step: 86 | Predicted movie_id: 142456 | reward: 4.0
# eval_mode: no
# Step: 87 | Predicted movie_id: 128832 | reward: 3.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 57243 | reward: 4.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 107069 | reward: 3.0
# eval_mode: no
# Step: 90 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 91 | Predicted movie_id: 158388 | reward: 2.5
# eval_mode: no
# Step: 92 | Predicted movie_id: 8575 | reward: 3.0
# eval_mode: no
# Step: 93 | Predicted movie_id: 1912 | reward: 4.0
# eval_mode: no
# Step: 94 | Predicted movie_id: 8946 | reward: 3.0
# eval_mode: no
# Step: 95 | Predicted movie_id: 1150 | reward: 4.5
# eval_mode: no
# Step: 96 | Predicted movie_id: 84716 | reward: 4.0
# eval_mode: no
# Step: 97 | Predicted movie_id: 3633 | reward: 3.5
# eval_mode: no
# Step: 98 | Predicted movie_id: 148166 | reward: 3.5
# eval_mode: no
# Step: 99 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 0 | Predicted movie_id: 202 | reward: 3.0
# eval_mode: no
# Step: 1 | Predicted movie_id: 62644 | reward: 3.5
# eval_mode: no
# Step: 2 | Predicted movie_id: 484 | reward: 3.0
# eval_mode: no
# Step: 3 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 4 | Predicted movie_id: 1969 | reward: 2.5
# eval_mode: no
# Step: 5 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 6 | Predicted movie_id: 6993 | reward: 4.0
# eval_mode: no
# Step: 7 | Predicted movie_id: 55814 | reward: 4.0
# eval_mode: no
# Step: 8 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 9 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 10 | Predicted movie_id: 140 | reward: 3.5
# eval_mode: no
# Step: 11 | Predicted movie_id: 2526 | reward: 2.0
# eval_mode: no
# Step: 12 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 13 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 14 | Predicted movie_id: 70637 | reward: 4.0
# eval_mode: no
# Step: 15 | Predicted movie_id: 100714 | reward: 3.5
# eval_mode: no
# Step: 16 | Predicted movie_id: 57243 | reward: 3.5
# eval_mode: no
# Step: 17 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 18 | Predicted movie_id: 4623 | reward: 3.5
# eval_mode: no
# Step: 19 | Predicted movie_id: 3473 | reward: 5.0
# eval_mode: no
# Step: 20 | Predicted movie_id: 166568 | reward: 4.5
# eval_mode: no
# Step: 21 | Predicted movie_id: 166492 | reward: 3.5
# eval_mode: no
# Step: 22 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 23 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 24 | Predicted movie_id: 84716 | reward: 4.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 791 | reward: 4.0
# eval_mode: no
# Step: 26 | Predicted movie_id: 86347 | reward: 3.5
# eval_mode: no
# Step: 27 | Predicted movie_id: 235 | reward: 3.5
# eval_mode: no
# Step: 28 | Predicted movie_id: 49647 | reward: 3.5
# eval_mode: no
# Step: 29 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 30 | Predicted movie_id: 132424 | reward: 2.0
# eval_mode: no
# Step: 31 | Predicted movie_id: 6254 | reward: 5.0
# eval_mode: no
# Step: 32 | Predicted movie_id: 136471 | reward: 3.5
# eval_mode: no
# Step: 33 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 34 | Predicted movie_id: 1021 | reward: 2.5
# eval_mode: no
# Step: 35 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 36 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 1955 | reward: 4.0
# eval_mode: no
# Step: 38 | Predicted movie_id: 168712 | reward: 1.0
# eval_mode: no
# Step: 39 | Predicted movie_id: 1340 | reward: 3.0
# eval_mode: no
# Step: 40 | Predicted movie_id: 44943 | reward: 5.0
# eval_mode: no
# Step: 41 | Predicted movie_id: 56060 | reward: 4.5
# eval_mode: no
# Step: 42 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 43 | Predicted movie_id: 4677 | reward: 3.0
# eval_mode: no
# Step: 44 | Predicted movie_id: 114494 | reward: 1.5
# eval_mode: no
# Step: 45 | Predicted movie_id: 26078 | reward: 5.0
# eval_mode: no
# Step: 46 | Predicted movie_id: 6666 | reward: 4.5
# eval_mode: no
# Step: 47 | Predicted movie_id: 148709 | reward: 2.0
# eval_mode: no
# Step: 48 | Predicted movie_id: 2418 | reward: 3.0
# eval_mode: no
# Step: 49 | Predicted movie_id: 64620 | reward: 4.0
# eval_mode: no
# Step: 50 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 51 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 52 | Predicted movie_id: 57421 | reward: 4.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 3053 | reward: 4.0
# eval_mode: no
# Step: 54 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 55 | Predicted movie_id: 6598 | reward: 3.5
# eval_mode: no
# Step: 56 | Predicted movie_id: 132424 | reward: 2.0
# eval_mode: no
# Step: 57 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 58 | Predicted movie_id: 76143 | reward: 4.5
# eval_mode: no
# Step: 59 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 60 | Predicted movie_id: 52579 | reward: 3.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 62 | Predicted movie_id: 175401 | reward: 4.0
# eval_mode: no
# Step: 63 | Predicted movie_id: 6158 | reward: 3.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 65 | Predicted movie_id: 179511 | reward: 4.0
# eval_mode: no
# Step: 66 | Predicted movie_id: 27772 | reward: 2.5
# eval_mode: no
# Step: 67 | Predicted movie_id: 8484 | reward: 4.5
# eval_mode: no
# Step: 68 | Predicted movie_id: 143969 | reward: 3.0
# eval_mode: no
# Step: 69 | Predicted movie_id: 27820 | reward: 4.0
# eval_mode: no
# Step: 70 | Predicted movie_id: 363 | reward: 4.0
# eval_mode: no
# Step: 71 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 2791 | reward: 5.0
# eval_mode: no
# Step: 73 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 74 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 75 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 76 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 77 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 78 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 79 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 80 | Predicted movie_id: 84553 | reward: 4.0
# eval_mode: no
# Step: 81 | Predicted movie_id: 56012 | reward: 3.0
# eval_mode: no
# Step: 82 | Predicted movie_id: 5984 | reward: 3.5
# eval_mode: no
# Step: 83 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 84 | Predicted movie_id: 36289 | reward: 4.0
# eval_mode: no
# Step: 85 | Predicted movie_id: 101962 | reward: 4.0
# eval_mode: no
# Step: 86 | Predicted movie_id: 1124 | reward: 3.5
# eval_mode: no
# Step: 87 | Predicted movie_id: 98230 | reward: 3.5
# eval_mode: no
# Step: 88 | Predicted movie_id: 6042 | reward: 3.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 8933 | reward: 4.0
# eval_mode: no
# Step: 90 | Predicted movie_id: 7762 | reward: 3.5
# eval_mode: no
# Step: 91 | Predicted movie_id: 80478 | reward: 4.0
# eval_mode: no
# Step: 92 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 93 | Predicted movie_id: 86059 | reward: 3.0
# eval_mode: no
# Step: 94 | Predicted movie_id: 27716 | reward: 4.5
# eval_mode: no
# Step: 95 | Predicted movie_id: 149354 | reward: 2.5
# eval_mode: no
# Step: 96 | Predicted movie_id: 1856 | reward: 4.0
# eval_mode: no
# Step: 97 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 98 | Predicted movie_id: 2374 | reward: 3.0
# eval_mode: no
# Step: 99 | Predicted movie_id: 6214 | reward: 4.0
# eval_mode: no
# Step: 0 | Predicted movie_id: 128832 | reward: 3.5
# eval_mode: no
# Step: 1 | Predicted movie_id: 158388 | reward: 2.5
# eval_mode: no
# Step: 2 | Predicted movie_id: 26761 | reward: 3.0
# eval_mode: no
# Step: 3 | Predicted movie_id: 100714 | reward: 3.5
# eval_mode: no
# Step: 4 | Predicted movie_id: 130450 | reward: 2.5
# eval_mode: no
# Step: 5 | Predicted movie_id: 59429 | reward: 3.0
# eval_mode: no
# Step: 6 | Predicted movie_id: 42011 | reward: 2.0
# eval_mode: no
# Step: 7 | Predicted movie_id: 34148 | reward: 3.0
# eval_mode: no
# Step: 8 | Predicted movie_id: 4350 | reward: 4.0
# eval_mode: no
# Step: 9 | Predicted movie_id: 96 | reward: 3.5
# eval_mode: no
# Step: 10 | Predicted movie_id: 85354 | reward: 3.5
# eval_mode: no
# Step: 11 | Predicted movie_id: 70703 | reward: 2.0
# eval_mode: no
# Step: 12 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 13 | Predicted movie_id: 79185 | reward: 3.5
# eval_mode: no
# Step: 14 | Predicted movie_id: 70641 | reward: 3.0
# eval_mode: no
# Step: 15 | Predicted movie_id: 1009 | reward: 3.0
# eval_mode: no
# Step: 16 | Predicted movie_id: 39715 | reward: 2.0
# eval_mode: no
# Step: 17 | Predicted movie_id: 104339 | reward: 4.0
# eval_mode: no
# Step: 18 | Predicted movie_id: 6201 | reward: 5.0
# eval_mode: no
# Step: 19 | Predicted movie_id: 73106 | reward: 2.0
# eval_mode: no
# Step: 20 | Predicted movie_id: 79798 | reward: 3.5
# eval_mode: no
# Step: 21 | Predicted movie_id: 2708 | reward: 4.0
# eval_mode: no
# Step: 22 | Predicted movie_id: 51662 | reward: 3.5
# eval_mode: no
# Step: 23 | Predicted movie_id: 27075 | reward: 3.0
# eval_mode: no
# Step: 24 | Predicted movie_id: 408 | reward: 3.0
# eval_mode: no
# Step: 25 | Predicted movie_id: 148166 | reward: 3.5
# eval_mode: no
# Step: 26 | Predicted movie_id: 5957 | reward: 3.5
# eval_mode: no
# Step: 27 | Predicted movie_id: 4381 | reward: 3.5
# eval_mode: no
# Step: 28 | Predicted movie_id: 79798 | reward: 3.5
# eval_mode: no
# Step: 29 | Predicted movie_id: 866 | reward: 4.0
# eval_mode: no
# Step: 30 | Predicted movie_id: 6811 | reward: 2.5
# eval_mode: no
# Step: 31 | Predicted movie_id: 37720 | reward: 3.0
# eval_mode: no
# Step: 32 | Predicted movie_id: 189 | reward: 3.0
# eval_mode: no
# Step: 33 | Predicted movie_id: 1771 | reward: 4.0
# eval_mode: no
# Step: 34 | Predicted movie_id: 65225 | reward: 4.5
# eval_mode: no
# Step: 35 | Predicted movie_id: 6973 | reward: 2.5
# eval_mode: no
# Step: 36 | Predicted movie_id: 1976 | reward: 2.0
# eval_mode: no
# Step: 37 | Predicted movie_id: 86347 | reward: 3.5
# eval_mode: no
# Step: 38 | Predicted movie_id: 93819 | reward: 3.5
# eval_mode: no
# Step: 39 | Predicted movie_id: 90863 | reward: 4.0
# eval_mode: no
# Step: 40 | Predicted movie_id: 2445 | reward: 2.5
# eval_mode: no
# Step: 41 | Predicted movie_id: 1340 | reward: 3.0
# eval_mode: no
# Step: 42 | Predicted movie_id: 31973 | reward: 3.5
# eval_mode: no
# Step: 43 | Predicted movie_id: 544 | reward: 2.5
# eval_mode: no
# Step: 44 | Predicted movie_id: 31522 | reward: 5.0
# eval_mode: no
# Step: 45 | Predicted movie_id: 8670 | reward: 4.0
# eval_mode: no
# Step: 46 | Predicted movie_id: 1331 | reward: 2.0
# eval_mode: no
# Step: 47 | Predicted movie_id: 91860 | reward: 4.0
# eval_mode: no
# Step: 48 | Predicted movie_id: 88179 | reward: 3.5
# eval_mode: no
# Step: 49 | Predicted movie_id: 8804 | reward: 5.0
# eval_mode: no
# Step: 50 | Predicted movie_id: 2794 | reward: 2.5
# eval_mode: no
# Step: 51 | Predicted movie_id: 685 | reward: 4.0
# eval_mode: no
# Step: 52 | Predicted movie_id: 7482 | reward: 4.0
# eval_mode: no
# Step: 53 | Predicted movie_id: 199 | reward: 4.0
# eval_mode: no
# Step: 54 | Predicted movie_id: 27744 | reward: 4.5
# eval_mode: no
# Step: 55 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 56 | Predicted movie_id: 202 | reward: 3.0
# eval_mode: no
# Step: 57 | Predicted movie_id: 91104 | reward: 2.0
# eval_mode: no
# Step: 58 | Predicted movie_id: 6816 | reward: 4.0
# eval_mode: no
# Step: 59 | Predicted movie_id: 71668 | reward: 3.5
# eval_mode: no
# Step: 60 | Predicted movie_id: 4168 | reward: 3.0
# eval_mode: no
# Step: 61 | Predicted movie_id: 6235 | reward: 4.5
# eval_mode: no
# Step: 62 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 63 | Predicted movie_id: 3634 | reward: 4.0
# eval_mode: no
# Step: 64 | Predicted movie_id: 1526 | reward: 1.0
# eval_mode: no
# Step: 65 | Predicted movie_id: 6158 | reward: 3.0
# eval_mode: no
# Step: 66 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no
# Step: 67 | Predicted movie_id: 148675 | reward: 2.0
# eval_mode: no
# Step: 68 | Predicted movie_id: 4160 | reward: 4.0
# eval_mode: no
# Step: 69 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 70 | Predicted movie_id: 86142 | reward: 4.0
# eval_mode: no
# Step: 71 | Predicted movie_id: 57421 | reward: 4.0
# eval_mode: no
# Step: 72 | Predicted movie_id: 5004 | reward: 3.5
# eval_mode: no
# Step: 73 | Predicted movie_id: 3707 | reward: 2.5
# eval_mode: no
# Step: 74 | Predicted movie_id: 7831 | reward: 3.5
# eval_mode: no
# Step: 75 | Predicted movie_id: 27744 | reward: 4.5
# eval_mode: no
# Step: 76 | Predicted movie_id: 6939 | reward: 4.0
# eval_mode: no
# Step: 77 | Predicted movie_id: 31225 | reward: 3.0
# eval_mode: no
# Step: 78 | Predicted movie_id: 8582 | reward: 4.0
# eval_mode: no
# Step: 79 | Predicted movie_id: 134184 | reward: 4.5
# eval_mode: no
# Step: 80 | Predicted movie_id: 1572 | reward: 3.0
# eval_mode: no
# Step: 81 | Predicted movie_id: 8033 | reward: 3.5
# eval_mode: no
# Step: 82 | Predicted movie_id: 55069 | reward: 4.0
# eval_mode: no
# Step: 83 | Predicted movie_id: 33132 | reward: 1.5
# eval_mode: no
# Step: 84 | Predicted movie_id: 190221 | reward: 1.0
# eval_mode: no
# Step: 85 | Predicted movie_id: 69436 | reward: 3.0
# eval_mode: no
# Step: 86 | Predicted movie_id: 1461 | reward: 2.5
# eval_mode: no
# Step: 87 | Predicted movie_id: 1955 | reward: 4.0
# eval_mode: no
# Step: 88 | Predicted movie_id: 117109 | reward: 3.0
# eval_mode: no
# Step: 89 | Predicted movie_id: 141513 | reward: 4.0
# eval_mode: no
# Step: 90 | Predicted movie_id: 2518 | reward: 3.0
# eval_mode: no
# Step: 91 | Predicted movie_id: 6625 | reward: 2.5
# eval_mode: no
# Step: 92 | Predicted movie_id: 6063 | reward: 3.5
# eval_mode: no
# Step: 93 | Predicted movie_id: 120637 | reward: 2.5
# eval_mode: no
# Step: 94 | Predicted movie_id: 75816 | reward: 2.0
# eval_mode: no
# Step: 95 | Predicted movie_id: 791 | reward: 4.0
# eval_mode: no
# Step: 96 | Predicted movie_id: 97024 | reward: 0.5
# eval_mode: no
# Step: 97 | Predicted movie_id: 122926 | reward: 4.0
# eval_mode: no
# Step: 98 | Predicted movie_id: 7305 | reward: 2.5
# eval_mode: no
# Step: 99 | Predicted movie_id: 44511 | reward: 3.5
# eval_mode: no

# %%
scaled_ep_rewards = [r * 100/ 500 for r in episode_rewards]
scaled_ep_rewards
# Out:
# [62.3, 64.7, 62.8, 65.1, 64.6, 62.8, 64.3, 66.8, 67.5, 65.4]

# %%
action_vocab.shape

# %%
# Another evaluation policy

# from stable_baselines3.common.evaluation import evaluate_policy
# # # Evaluate the trained model
# with open('data/test_data_with_naive_rewards.pkl', 'rb') as f:
#     test_data = pickle.load(f)
# test_env = Monitor(create_custom_env(test_data))

# mean_reward, another = evaluate_policy(model, test_env, n_eval_episodes=5, return_episode_rewards=True)
# mean_reward, another
# # # Use the trained model to interact with the environment
# # # test_env = make_vec_env(create_custom_env, num_envs=1)
# # test_env = create_custom_env(test_data)
# # obs = test_env.reset()[0]
# # # print(f"obs: {obs}; shape: {obs.shape}")
# # rewards = []
# # for _ in range(1000):
# #     action, _ = model.predict(obs, deterministic=True)
# #     # print(f"action: {action}, type: {type(action)}, shape: {action.shape}")
# #     obs, reward, done, _, info = test_env.step(action.item())
# #     print(f"reward: {reward}")
# #     rewards.append(reward)
# #     if done:
# #         obs, _ = test_env.reset()
